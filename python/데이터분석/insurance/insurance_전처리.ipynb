# %%
import pandas as pd
from ydata_profiling import ProfileReport

import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', 40)
# Out:
# C:\Users\kyeul\AppData\Local\Temp\ipykernel_12908\175995752.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
def data_summary(df):
    """
    주어진 DataFrame에서 각 열의 요약 통계를 계산하고 결과를 새로운 DataFrame으로 반환한다.

    Parameters:
        df (DataFrame): 분석할 데이터를 포함한 pandas DataFrame.

    Returns:
        DataFrame: 각 열의 데이터 타입, 개수, 고유값 개수, 결측치 개수, 결측치 비율, 고유값을 포함한 요약 정보.
    """
    obs = df.shape[0]
    types = df.dtypes
    counts = df.apply(lambda x: x.count())
    uniques = df.apply(lambda x: [x.unique()]).T.squeeze()
    nulls = df.apply(lambda x: x.isnull().sum())
    distincts = df.apply(lambda x: x.unique().shape[0])
    missing_ratio = (df.isnull().sum() / obs)*100
    
    print("Data shape: ", df.shape)

    cols = ['Types', 'Counts', 'Distincts', 'Nulls', 'Missing_ratio', 'Uniques']
    structure = pd.concat([types, counts, distincts, nulls, missing_ratio, uniques], axis=1, sort=True)

    structure.columns = cols

    print("================================================")
    print("Data types: ")
    print(structure['Types'].value_counts())
    print("================================================")
    print("\n\n")

    return structure

# %%
data = pd.read_excel('보험데이터_체증형_통합.xlsx')

# %%
data_summary(data)
# Out:
# Data shape:  (71, 11)
# ================================================
# Data types:
# Types
# object     7
# int64      3
# float64    1
# Name: count, dtype: int64
# ================================================
#              Types  Counts  Distincts  Nulls  Missing_ratio  \
# 그룹          object      20          7     51      71.830986
# 기본 보험료       int64      71         59      0       0.000000
# 납입기간/보험기간   object      71          5      0       0.000000
# 보장금액         int64      71         23      0       0.000000
# 보장단위        object      71          4      0       0.000000
# 보험 보장 대상    object      71         71      0       0.000000
# 상세 설명       object      71         71      0       0.000000
# 유형1         object      71          6      0       0.000000
# 유형2         object      71         14      0       0.000000
# 총 보험료        int64      71         59      0       0.000000
# 할증 보험료     float64      17         14     54      76.056338
#
#                                            Uniques
# 그룹                         [nan, f, b, c, d, e, a]
# 기본 보험료     [7305, 393, 17265, 2374, 7695, 396, ...
# 납입기간/보험기간  [20년납 100세만기, 20년납\n100세만기, 20년갱신 10...
# 보장금액       [150000, 30000, 10000, 100000000, 20...
# 보장단위                       [1일, 발생시, 최초 1회, 연간 1회]
# 보험 보장 대상   [(체증형)상해 입원 간병인 사용일당(1일이상)(요양병원 제외),...
# 상세 설명      [상해사고로 병·의원(요양병원 제외) 등에 1일이상 계속 입원하여...
# 유형1                 [입원, 생활, 수술, 진단, 간병/사망, 장해/장애]
# 유형2        [간병인1, 간병인2, 일상배상, 로봇수술, 질병, 골절, 갑상선...
# 총 보험료      [7305, 393, 25297, 3438, 7695, 396, ...
# 할증 보험료     [nan, 8032.0, 1064.0, 8493.0, 3207.0...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   유형1        71 non-null     object
#  1   유형2        71 non-null     object
#  2   보험 보장 대상   71 non-null     object
#  3   상세 설명      71 non-null     object
#  4   보장단위       71 non-null     object
#  5   보장금액       71 non-null     int64
#  6   총 보험료      71 non-null     int64
#  7   기본 보험료     71 non-null     int64
#  8   할증 보험료     17 non-null     float64
#  9   납입기간/보험기간  71 non-null     object
#  10  그룹         20 non-null     object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 6.2+ KB

# %%
data.sample(10)
# Out:
#       유형1   유형2                                 보험 보장 대상  \
# 39     입원    상해              상해 입원 간호·간병통합서비스 사용일당(1일이상)
# 38  간병/사망    상해                                    상해 사망
# 44     진단     암                               유사암진단 납입지원
# 43     진단     암  암(기타피부암및갑상선암제외) 진단후 암특정치료비(진단후5년,연간1회한)
# 9      수술  로봇수술                [갱신형] 암(특정암 제외) 다빈치로봇 수술비
# 65     수술    질병                          질병 8종 수술비(시술포함)
# 37     수술    상해                                상해 골절 수술비
# 35     수술    상해                          상해 7종 수술비(시술포함)
# 13     수술    질병                      111대질병 수술비(22대주요질병)
# 8      생활  일상배상                     [갱신형] 가족 일상생활중 배상책임Ⅱ
#
#                                       상세 설명   보장단위       보장금액  총 보험료  기본 보험료  \
# 39  상해사고로 병원(요양병원 제외)에 1일이상 계속 입원하여 치료를 ...     1일      70000    805     805
# 38                     상해사고로 사망한 경우 가입금액 지급    발생시   50000000   2550    2550
# 44  이 특별약관의 보험기간 중 「기타피부암」,「갑상선암」,「대장점막내...    발생시      66000    488     488
# 43  보장개시일 이후 암으로 진단 확정되고 「암(기타피부암 및 갑상선암...  연간 1회   10000000  14630   14630
# 9   보장개시일 이후 암(특정암 제외)으로 진단 확정되고 그 암(특정암...  최초 1회   20000000   1120    1120
# 65  보험기간 중 질병의 치료를 직접적인 목적으로 약관에서 정한 8종 ...  연간 1회   15000000   5056    3410
# 37         상해사고로 약관에 정한 골절로 수술받은 경우 가입금액 지급    발생시     200000    372     372
# 35  보험기간 중 상해의 치료를 직접적인 목적으로 약관에서 정한 7종 ...  연간 1회   15000000    266     266
# 13  보험기간 중 약관에 정한 22대 주요질병으로 진단 확정되고 그 치...    발생시    1000000    704     482
# 8   본인 및 약관에 정한 가족의 일상생활 및 보험증권에 기재된 주택의...    발생시  100000000   1154    1154
#
#     할증 보험료     납입기간/보험기간   그룹
# 39     NaN   20년납 100세만기  NaN
# 38     NaN   20년납 100세만기  NaN
# 44     NaN    20년납 20년만기  NaN
# 43     NaN   20년납 100세만기  NaN
# 9      NaN  10년갱신 100세만기  NaN
# 65  1646.0   20년납 100세만기    e
# 37     NaN   20년납 100세만기  NaN
# 35     NaN   20년납 100세만기    c
# 13   222.0   20년납 100세만기  NaN
# 8      NaN  20년갱신 100세만기  NaN

# %%
# help(ProfileReport)

# %%
# profile = ProfileReport(data, title="Profiling Report")
# profile

# %% [markdown]
# ## 데이터 전처리

# %%
def split_data(x):
    """납입기간과 보험기간을 분리"""
    if ' ' in x:
        period = x.split(' ')[0]
        guarantee = x.split(' ')[1]
    elif '\n' in x:
        period = x.split('\n')[0]
        guarantee = x.split('\n')[1]

    return [period, guarantee]

# %%
data[['납입기간', '보장기간']] = data['납입기간/보험기간'].apply(lambda x: pd.Series(split_data(x)))

# %%
data.drop('납입기간/보험기간', inplace=True, axis=1)
data.sample(10)
# Out:
#    유형1   유형2                                 보험 보장 대상  \
# 37  수술    상해                                상해 골절 수술비
# 23  진단    골절                                   골절 진단비
# 22  진단   갑상선                             갑상선기능항진증 치료비
# 0   입원  간병인1       (체증형)상해 입원 간병인 사용일당(1일이상)(요양병원 제외)
# 53  진단     암      종합병원 암 특정치료지원금(연간 6천만원 이상, 진단 후 5년)
# 43  진단     암  암(기타피부암및갑상선암제외) 진단후 암특정치료비(진단후5년,연간1회한)
# 34  수술    상해                          상해 6종 수술비(시술포함)
# 29  수술    상해                          상해 1종 수술비(시술포함)
# 8   생활  일상배상                     [갱신형] 가족 일상생활중 배상책임Ⅱ
# 6   입원  간병인2  (체증형,20년후2배)질병 입원 간병인 사용일당(1 일이상)(요양...
#
#                                       상세 설명   보장단위       보장금액  총 보험료  기본 보험료  \
# 37         상해사고로 약관에 정한 골절로 수술받은 경우 가입금액 지급    발생시     200000    372     372
# 23       상해사고로 약관에 정한 골절로 진단 확정된 경우 가입금액 지급    발생시     100000    898     898
# 22  보험기간 중 약관에서 정한 「갑상선기능항진증」으로 진단 확정되고 ...  최초 1회    2000000    260     260
# 0   상해사고로 병·의원(요양병원 제외) 등에 1일이상 계속 입원하여 ...     1일     150000   7305    7305
# 53  보장개시일 이후 암, 기타피부암 또는 갑상선암으로 진단 확정되고 ...  연간 1회   10000000    638     638
# 43  보장개시일 이후 암으로 진단 확정되고 「암(기타피부암 및 갑상선암...  연간 1회   10000000  14630   14630
# 34  보험기간 중 상해의 치료를 직접적인 목적으로 약관에서 정한 6종 ...  연간 1회   10000000    266     266
# 29  보험기간 중 상해의 치료를 직접적인 목적으로 약관에서 정한 1종 ...  연간 1회     300000    546     546
# 8   본인 및 약관에 정한 가족의 일상생활 및 보험증권에 기재된 주택의...    발생시  100000000   1154    1154
# 6   보험기간 중 질병으로 병·의원(요양병원 제외) 등에 1일이상 계속...     1일     150000  26733   18240
#
#     할증 보험료   그룹   납입기간    보장기간
# 37     NaN  NaN   20년납  100세만기
# 23     NaN  NaN   20년납  100세만기
# 22     NaN  NaN   20년납  100세만기
# 0      NaN  NaN   20년납  100세만기
# 53     NaN  NaN   20년납  100세만기
# 43     NaN  NaN   20년납  100세만기
# 34     NaN    c   20년납  100세만기
# 29     NaN    b   20년납  100세만기
# 8      NaN  NaN  20년갱신  100세만기
# 6   8493.0  NaN   20년납  100세만기

# %%
data['보험기간'].value_counts()
# Out:
# 보험기간
# 100세만기    70
# 20년만기      1
# Name: count, dtype: int64

# %%
data[data['보험기간']=='20년만기']
# Out:
#    유형1 유형2    보험 보장 대상                                    상세 설명 보장단위   보장금액  \
# 44  진단   암  유사암진단 납입지원  이 특별약관의 보험기간 중 「기타피부암」,「갑상선암」,「대장점막내...  발생시  66000
#
#     총 보험료  기본 보험료  할증 보험료   그룹  납입기간   보험기간
# 44    488     488     NaN  NaN  20년납  20년만기

# %%
# ['보험기간', '갱신']으로 나누기
data[['납입기간(년)', '갱신여부']] = data['납입기간'].str.split('년', expand=True)
data.drop('납입기간', inplace=True, axis=1)
data.sample(10)
# Out:
#    유형1   유형2                             보험 보장 대상  \
# 44  진단     암                           유사암진단 납입지원
# 29  수술    상해                      상해 1종 수술비(시술포함)
# 30  수술    상해                      상해 2종 수술비(시술포함)
# 64  수술    질병                      질병 7종 수술비(시술포함)
# 50  진단     암  종합병원 암 특정치료지원금(연간 3천만원 이상, 진단 후 5년)
# 15  수술    질병                 111대질병 수술비(5대주요기관관혈)
# 26  진단     암                  기타피부암 및 갑상선암 치료비 지원
# 46  수술  인공관절                           인공관절치환 수술비
# 19  수술    질병                  4대특정질병 치료·수술비(선천이상)
# 28  진단    상해                          보험료 납입면제대상Ⅱ
#
#                                       상세 설명   보장단위      보장금액  총 보험료  기본 보험료  \
# 44  이 특별약관의 보험기간 중 「기타피부암」,「갑상선암」,「대장점막내...    발생시     66000    488     488
# 29  보험기간 중 상해의 치료를 직접적인 목적으로 약관에서 정한 1종 ...  연간 1회    300000    546     546
# 30  보험기간 중 상해의 치료를 직접적인 목적으로 약관에서 정한 2종 ...  연간 1회    300000    546     546
# 64  보험기간 중 질병의 치료를 직접적인 목적으로 약관에서 정한 7종 ...  연간 1회   9000000   5056    3410
# 50  보장개시일 이후 암, 기타피부암 또는 갑상선암으로 진단 확정되고 ...  연간 1회  10000000   1581    1581
# 15  보험기간 중 약관에 정한 뇌질환, 심질환, 간·췌장질환 및 폐질환...    발생시  20000000   7320    7320
# 26  보장개시일 이후 기타피부암 또는 갑상선암으로 진단 확정된 경우 가...  최초 1회    100000     12      12
# 46  보험기간 중 상해 또는 질병으로 약관에 정한 인공관절치환 수술을 ...  최초 1회   2500000    775     775
# 19  보험기간 중 약관에 정한 선천성이상 질병의 치료를 직접적인 목적으...  연간 1회    200000    124     124
# 28  보장개시일 이후 상해사고로 80%이상 후유장해가 발생하거나 약관에...  최초 1회    100000    168     168
#
#     할증 보험료   그룹    보장기간 납입기간(년) 갱신여부
# 44     NaN  NaN   20년만기      20    납
# 29     NaN    b  100세만기      20    납
# 30     NaN    b  100세만기      20    납
# 64  1646.0    e  100세만기      20    납
# 50     NaN  NaN  100세만기      20    납
# 15     NaN  NaN  100세만기      20    납
# 26     NaN  NaN  100세만기      20    납
# 46     NaN  NaN  100세만기      20    납
# 19     NaN    f  100세만기      20    납
# 28     NaN  NaN  100세만기      20    납

# %%
data[data['갱신여부']!='납']
# Out:
#    유형1   유형2                   보험 보장 대상  \
# 8   생활  일상배상       [갱신형] 가족 일상생활중 배상책임Ⅱ
# 9   수술  로봇수술  [갱신형] 암(특정암 제외) 다빈치로봇 수술비
# 10  수술  로봇수술        [갱신형] 특정암 다빈치로봇 수술비
# 11  생활  일상배상   [공제][갱신형] 가족 일상생활중 배상책임Ⅱ
#
#                                       상세 설명   보장단위       보장금액  총 보험료  기본 보험료  \
# 8   본인 및 약관에 정한 가족의 일상생활 및 보험증권에 기재된 주택의...    발생시  100000000   1154    1154
# 9   보장개시일 이후 암(특정암 제외)으로 진단 확정되고 그 암(특정암...  최초 1회   20000000   1120    1120
# 10  보장개시일 이후 특정암(갑상선암, 전립선암)으로 진단 확정되고 그...  최초 1회   10000000    200     200
# 11  ※ 1사고당 자기부담금 : 대인 없음, 대물누수사고 50만원, 대...    발생시     500000      0       0
#
#     할증 보험료   그룹    보장기간 납입기간(년) 갱신여부
# 8      NaN  NaN  100세만기      20   갱신
# 9      NaN  NaN  100세만기      10   갱신
# 10     NaN  NaN  100세만기      10   갱신
# 11     NaN  NaN  100세만기      20   갱신

# %%
data.rename(columns={'납/갱':'납입/갱신'}, inplace=True)

# %%
# 항목별 전체 납입액 구하기
data.rename(columns={'총 보험료':'월 보험료'}, inplace=True)

# %%
data['총 보험료'] = data['월 보험료'] * data['납입기간(년)'].astype('int') * 12
data.head(10)
# Out:
#   유형1   유형2                                 보험 보장 대상  \
# 0  입원  간병인1       (체증형)상해 입원 간병인 사용일당(1일이상)(요양병원 제외)
# 1  입원  간병인1          (체증형)상해 입원 간병인 사용일당(1일이상)(요양병원)
# 2  입원  간병인1       (체증형)질병 입원 간병인 사용일당(1일이상)(요양병원 제외)
# 3  입원  간병인1          (체증형)질병 입원 간병인 사용일당(1일이상)(요양병원)
# 4  입원  간병인2  (체증형,20년후2배)상해 입원 간병인 사용일당(1 일이상)(요양...
# 5  입원  간병인2  (체증형,20년후2배)상해 입원 간병인 사용일당(1 일이상)(요양병원)
# 6  입원  간병인2  (체증형,20년후2배)질병 입원 간병인 사용일당(1 일이상)(요양...
# 7  입원  간병인2  (체증형,20년후2배)질병 입원 간병인 사용일당(1 일이상)(요양병원)
# 8  생활  일상배상                     [갱신형] 가족 일상생활중 배상책임Ⅱ
# 9  수술  로봇수술                [갱신형] 암(특정암 제외) 다빈치로봇 수술비
#
#                                      상세 설명   보장단위       보장금액  월 보험료  기본 보험료  \
# 0  상해사고로 병·의원(요양병원 제외) 등에 1일이상 계속 입원하여 ...     1일     150000   7305    7305
# 1  상해사고로 요양병원에 1일이상 계속 입원하여 치료를 받으며, 약관...     1일      30000    393     393
# 2  보험기간 중 질병으로 병·의원(요양병원 제외) 등에 1일이상 계속...     1일     150000  25297   17265
# 3  보험기간 중 질병으로 요양병원에 1일이상 계속 입원하여 치료를 받...     1일      10000   3438    2374
# 4  상해사고로 병·의원(요양병원 제외) 등에 1일이상 계속 입원하여 ...     1일     150000   7695    7695
# 5  상해사고로 요양병원에 1일이상 계속 입원하여 치료를 받으며, 약관...     1일      30000    396     396
# 6  보험기간 중 질병으로 병·의원(요양병원 제외) 등에 1일이상 계속...     1일     150000  26733   18240
# 7  보험기간 중 질병으로 요양병원에 1일이상 계속 입원하여 치료를 받...     1일      30000  10338    7131
# 8  본인 및 약관에 정한 가족의 일상생활 및 보험증권에 기재된 주택의...    발생시  100000000   1154    1154
# 9  보장개시일 이후 암(특정암 제외)으로 진단 확정되고 그 암(특정암...  최초 1회   20000000   1120    1120
#
#    할증 보험료   그룹    보장기간 납입기간(년) 갱신여부    총 보험료
# 0     NaN  NaN  100세만기      20    납  1753200
# 1     NaN  NaN  100세만기      20    납    94320
# 2  8032.0  NaN  100세만기      20    납  6071280
# 3  1064.0  NaN  100세만기      20    납   825120
# 4     NaN  NaN  100세만기      20    납  1846800
# 5     NaN  NaN  100세만기      20    납    95040
# 6  8493.0  NaN  100세만기      20    납  6415920
# 7  3207.0  NaN  100세만기      20    납  2481120
# 8     NaN  NaN  100세만기      20   갱신   276960
# 9     NaN  NaN  100세만기      10   갱신   134400

# %%
# 보장 받는 것에 비해 얼마나 많이 낼까?
data['보장 대비 납입율'] = data['총 보험료'] / data['보장금액']

# %% [markdown]
# ## Text Summarization

# %%
import pandas as pd

import ast
import re
import traceback

from ChatGPT_API import request_openai
# Out:
# C:\Users\kyeul\AppData\Local\Temp\ipykernel_13096\3441596423.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_excel('preprocessed_data.xlsx')
# data.head()

# %%
# 배치 프로세싱을 어떻게 진행할 것인가. 하나의 qeury에 여러 메시지를 담아야하고, 그 결과를 분리해서 받을 수 있어야 한다. 
# 그렇다면 문장 요약에서 내가 얻고 싶은 정보는 무엇일까? 
# 1. 어떤 병을 대상으로 한 보험인지. 사실 이거면 된다. 보장 내용은 내가 수작업으로 했으니까.

# %%
N_BATCH = 5

# %%
data_list = data['상세 설명'].to_list()

# 예시 데이터, '상세 설명' 키에 여러 상세 내용이 리스트로 저장되어 있다고 가정
temp = {
    '상세 설명': [f'{i}' for i in data_list],  # 1부터 71까지의 상세 내용 예시
}

# 문서 내용을 담을 빈 문자열 초기화
contents = []

doc_index = 0
# 10개씩 상세 설명을 문서 내용에 포맷팅하여 추가
for i in range(0, len(data_list), N_BATCH):
    
    content = ''

    chunk = temp['상세 설명'][i:i+N_BATCH]
    for detail in chunk:
        content += f"""
        index: {doc_index}
        <문서 내용>
        {detail}

        """
        doc_index += 1
    
    contents.append(content)

# %%
gpt_responses = []

for ducument_content in contents:
    result = request_openai(ducument_content)
    gpt_responses.append(result)

# %%
for i in gpt_responses:
    print(i)
# Out:
# ```
# {
#     'index': [0, 1, 2, 3, 4],
#     '보험 발생(질병)': ['간병인', '간병인', '간병인', '간병인', '간병인'],
#     '보장 횟수': ['1일당', '1일당', '1일당', '1일당', '1일당'],
#     '내용 요약': [
#         '상해로 1일 이상 입원 시 간병인 사용에 따라 일당 지급. 7만원 미만 50%, 7만원 이상 100% 할증 지급, 최대 180일.',
#         '요양병원에서 1일 이상 입원 시 간병인 사용에 따라 가입금액을 매5년마다 10%씩 정액 할증한 금액을 지급, 최대 180일.',
#         '질병으로 1일 이상 입원 시 간병인 사용에 따라 일당 지급. 7만원 미만 50%, 7만원 이상 100% 할증 지급, 최대 180일.',
#         '질병으로 요양병원에서 1일 이상 입원 시 간병인 사용에 따라 가입금액을 매5년마다 10%씩 정액 할증한 금액을 지급, 최대 180일.',
#         '상해로 1일 이상 입원 시 간병인 사용에 따라 일당 지급. 7만원 미만 50%, 7만원 이상 100% 할증 지급, 최대 180일.'
#     ]
# }
# ```
# ```
# {
#     'index': [5, 6, 7, 8, 9],
#     '보험 발생(질병)': ['간병인', '간병인', '간병인', '사고', '암(특정암 제외)'],
#     '보장 횟수': ['가입후 20년 미만/가입후 20년 이상', '1일당', '가입후 20년 미만/가입후 20년 이상', '1사고당', '최초 1회'],
#     '내용 요약': [
#         '상해로 요양병원 1일 이상 입원 시 간병인 사용에 따라 일당 지급. 20년 미만 100%, 20년 이상 200% 지급, 최대 180일.',
#         '질병으로 1일 이상 입원 시 간병인 사용에 따라 일당 지급. 7만원 미만 50% 또는 100%, 7만원 이상 100% 또는 200% 지급, 최대 180일.',
#         '질병으로 요양병원 1일 이상 입원 시 간병인 사용에 따라 일당 지급. 20년 미만 100%, 20년 이상 200% 지급, 최대 180일.',
#         '법률상 배상책임 발생시 가입금액 한도로 보상',
#         '암(특정암 제외) 진단 후 다빈치 수술 시 가입금액 지급, 보장개시 90일 후, 초기 감액 있음. (특정암: 갑상선암, 전립선암)'
#     ]
# }
# ```
# ```
# {
#     'index': [10, 11, 12, 13, 14],
#     '보험 발생(질병)': ['갑상선암, 전립선암', '사고', '19대 생활질병', '22대 주요질병', '갑상선질환, 고혈압 및 당뇨병'],
#     '보장 횟수': ['최초 1회', '1사고당', '수술당 1회', '수술당 1회', '수술당 1회'],
#     '내용 요약' : [
#         '특정암 진단 후 다빈치 수술 시 가입금액 지급, 보장개시 90일 후, 초기 감액 있음.',
#         '1사고당 자기부담금: 대인 없음, 대물누수 50만원, 기타 대물 20만원',
#         '19대 생활질병 수술 시 가입금액 지급, 1년 미만 50% 감액.',
#         '22대 주요질병 수술 시 가입금액 지급, 1년 미만 50% 감액.',
#         '갑상선질환, 고혈압 및 당뇨병 수술 시 가입금액 지급, 1년 미만 50% 감액.'
#     ],
# }
# ```
# ```
# {
#     'index': [15, 16, 17, 18, 19],
#     '보험 발생(질병)': ['뇌질환, 심질환, 간·췌장질환 및 폐질환', '뇌질환, 심질환, 간·췌장질환 및 폐질환', '62대 생활질병', '체외충격파쇄석술(급여), 제왕절개만출술(급여), 요실금', '선천성이상 질병'],
#     '보장 횟수': ['수술당 1회', '수술당 1회', '수술당 1회', '연간 1회한', '연간 1회한'],
#     '내용 요약': [
#         '뇌, 심, 간·췌장, 폐질환 관혈수술 시 가입금액 지급, 1년 미만 50% 감액.',
#         '뇌, 심, 간·췌장, 폐질환 비관혈수술 시 가입금액 지급, 1년 미만 50% 감액.',
#         '62대 생활질병 수술 시 가입금액 지급, 1년 미만 50% 감액.',
#         '체외충격파쇄석술(급여), 제왕절개만출술(급여), 요실금 수술 시 가입금액 지급, 1년 미만 50% 감액.',
#         '선천성이상 질병 수술 시 가입금액 지급, 1년 미만 50% 감액.'
#     ]
# }
# ```
# ```
# {
#     'index': [20, 21, 22, 23, 24],
#     '보험 발생(질병)': ['5대골절 수술', '갑상선기능저하증', '갑상선기능항진증', '골절', '골절(치아파절 제외)'],
#     '보장 횟수': ['수술받은 경우', '최초 1회', '최초 1회', '진단 확정된 경우', '진단 확정된 경우'],
#     '내용 요약': [
#         '5대 골절 수술 시 가입금액 지급',
#         '갑상선기능저하증 진단 후 가입금액 지급, 1년 미만 50% 감액',
#         '갑상선기능항진증 진단 후 갑상선기능항진증 치료 받을 경우 가입금액 지급, 1년 미만 50% 감액',
#         '골절 진단시 가입금액 지급',
#         '골절(치아파절 제외) 진단시 가입금액 지급'
#     ]
# }
# ```
# ```
# {
#     'index': [25, 26, 27, 28, 29],
#     '보험 발생(질병)': ['기타피부암, 갑상선암', '기타피부암, 갑상선암', '상해, 질병', '상해, 암, 뇌졸중, 심근경색증, 화상부식, 뇌내장손상수술', '상해'],
#     '보장 횟수': ['연간 1회', '최초 1회', '치료시', '최초 1회', '수술시'],
#     '내용 요약': [
#         '기타피부암 또는 갑상선암 진단 후 특정치료 받을 시 가입금액 지급',
#         '기타피부암 또는 갑상선암 진단시 최초 1회 가입금액 지급',
#         '상해 또는 질병으로 깁스치료 시 가입금액 지급, 부목치료 제외',
#         '80%이상 후유장해, 암, 뇌졸중, 심근경색증, 화상부식, 뇌·내장손상 수술시 가입금액 지급',
#         '상해 치료시 1종 수술 및 시술 받을 경우 가입금액 지급, 1회당 1회 보장'
#     ]
# }
# ```
# ```
# {
#     'index': [30, 31, 32, 33, 34],
#     '보험 발생(질병)': ['상해', '상해', '상해', '상해', '상해'],
#     '보장 횟수': ['수술시술코드당 연간1회한', '수술시술코드당 연간1회한', '수술시술코드당 연간1회한', '수술시술코드당 연간1회한', '수술시술코드당 연간1회한'],
#     '내용 요약': [
#         '상해의 치료를 직접적인 목적으로 약관에서 정한 2종 수술 및 시술을 받은 경우 가입금액 지급(수술시술코드당 연간1회한), 1회의 입원당 1회의 「수술 및 시술」 또는 1회의 통원당 1회의 「수술 및 시술」에 한하여 보장',
#         '상해의 치료를 직접적인 목적으로 약관에서 정한 3종 수술 및 시술을 받은 경우 가입금액 지급(수술시술코드당 연간1회한), 1회의 입원당 1회의 「수술 및 시술」 또는 1회의 통원당 1회의 「수술 및 시술」에 한하여 보장',
#         '상해의 치료를 직접적인 목적으로 약관에서 정한 4종 수술 및 시술을 받은 경우 가입금액 지급(수술시술코드당 연간1회한), 1회의 입원당 1회의 「수술 및 시술」 또는 1회의 통원당 1회의 「수술 및 시술」에 한하여 보장',
#         '상해의 치료를 직접적인 목적으로 약관에서 정한 5종 수술 및 시술을 받은 경우 가입금액 지급(수술시술코드당 연간1회한), 1회의 입원당 1회의 「수술 및 시술」 또는 1회의 통원당 1회의 「수술 및 시술」에 한하여 보장',
#         '상해의 치료를 직접적인 목적으로 약관에서 정한 6종 수술 및 시술을 받은 경우 가입금액 지급(수술시술코드당 연간1회한), 1회의 입원당 1회의 「수술 및 시술」 또는 1회의 통원당 1회의 「수술 및 시술」에 한하여 보장'
#     ]
# }
# ```
# ```
# {
#     'index': [35, 36, 37, 38, 39],
#     '보험 발생(질병)': ['상해', '상해', '골절', '사망', '간호·간병통합서비스'],
#     '보장 횟수': ['수술시술코드당 연간1회한', '수술시술코드당 연간1회한', '수술받은 경우', '한 번', '1일당'],
#     '내용 요약': [
#         '상해의 치료를 위해 약관에서 정한 7종 수술 및 시술을 받을 경우 가입금액 지급, 1회의 입원 또는 통원당 1회 보장',
#         '상해의 치료를 위해 약관에서 정한 8종 수술 및 시술을 받을 경우 가입금액 지급, 1회의 입원 또는 통원당 1회 보장',
#         '골절로 수술받은 경우 가입금액 지급',
#         '상해사고로 사망한 경우 가입금액 지급',
#         '상해로 입원하여 간호·간병통합서비스를 받은 경우 가입금액 지급, 최대 180일'
#     ]
# }
# ```
# ```
# {
#     'index': [40, 41, 42, 43, 44],
#     '보험 발생(질병)': ['후유장해', '아킬레스힘줄손상', '암', '암', '기타피부암, 갑상선암, 대장점막내암, 제자리암, 경계성종양'],
#     '보장 횟수': ['한도로', '수술받은 경우', '최초 1회', '연간 1회', '차회 이후'],
#     '내용 요약': [
#         '상해로 후유장해 발생 시 가입금액 한도로 지급',
#         '상해로 아킬레스힘줄손상 수술 시 가입금액 지급',
#         '암 진단 후 최초 1회 가입금액 지급, 보장개시 90일 후',
#         '암 진단 후 특정치료 받을 경우 연간 1회 가입금액 지급, 보장개시 90일 후, 지급기간 5년까지',
#         '기타피부암, 갑상선암, 대장점막내암, 제자리암, 경계성종양 진단 시 차회 이후 보험료 납입 시 이 특별약관 가입금액 지원'
#     ]
# }
# ```
# ```
# {
#     'index': [45, 46, 47, 48, 49],
#     '보험 발생(질병)': ['아나필락시스', '인공관절치환', '암, 기타피부암, 갑상선암', '암, 기타피부암, 갑상선암', '암, 기타피부암, 갑상선암'],
#     '보장 횟수': ['연간 1회', '최초 1회', '연간 1회', '연간 1회', '연간 1회'],
#     '내용 요약': [
#         '응급실 내원 시 아나필락시스로 진단 확정 시 가입금액 지급',
#         '상해 또는 질병으로 인공관절치환 수술 시 가입금액 지급 (고, 슬, 견관절에 한함)',
#         '암, 기타피부암, 갑상선암 진단 후 암 특정치료 받을 경우 1억원 이상시 가입금액 지급',
#         '암, 기타피부암, 갑상선암 진단 후 암 특정치료 받을 경우 1천만원 이상시 가입금액 지급',
#         '암, 기타피부암, 갑상선암 진단 후 암 특정치료 받을 경우 2천만원 이상시 가입금액 지급'
#     ]
# }
# ```
# ```
# {
#     'index': [50, 51, 52, 53, 54],
#     '보험 발생(질병)': ['암, 기타피부암, 갑상선암', '암, 기타피부암, 갑상선암', '암, 기타피부암, 갑상선암', '암, 기타피부암, 갑상선암', '암, 기타피부암, 갑상선암'],
#     '보장 횟수': ['연간 1회한', '연간 1회한', '연간 1회한', '연간 1회한', '연간 1회한'],
#     '내용 요약': [
#         '암, 기타피부암, 갑상선암으로 진단 후 3천만원 이상의 연간 암 특정치료비 발생 시 가입금액 지급',
#         '암, 기타피부암, 갑상선암으로 진단 후 4천만원 이상의 연간 암 특정치료비 발생 시 가입금액 지급',
#         '암, 기타피부암, 갑상선암으로 진단 후 5천만원 이상의 연간 암 특정치료비 발생 시 가입금액 지급',
#         '암, 기타피부암, 갑상선암으로 진단 후 6천만원 이상의 연간 암 특정치료비 발생 시 가입금액 지급',
#         '암, 기타피부암, 갑상선암으로 진단 후 7천만원 이상의 연간 암 특정치료비 발생 시 가입금액 지급'
#     ]
# }
# ```
# ```
# {
#     'index': [55, 56, 57, 58, 59],
#     '보험 발생(질병)': ['암, 기타피부암, 갑상선암', '암, 기타피부암, 갑상선암', '화상 또는 부식', '질병', '질병'],
#     '보장 횟수': ['연간 1회한', '연간 1회한', '최초 1회한', '수술시술코드당 연간1회한', '수술시술코드당 연간1회한'],
#     '내용 요약' : [
#         '암 특정치료비 총액 8천만원 이상의 암, 기타피부암, 갑상선암 진단 후 특정치료 받을 시 가입금액 지급',
#         '암 특정치료비 총액 9천만원 이상의 암, 기타피부암, 갑상선암 진단 후 특정치료 받을 시 가입금액 지급',
#         '신체 표면적으로 최소 20% 이상의 3도 화상 또는 부식을 입은 경우 가입금액 지급',
#         '질병 치료를 위해 1종 수술 및 시술을 받을 시 가입금액 지급',
#         '질병 치료를 위해 2종 수술 및 시술을 받을 시 가입금액 지급',
#     ],
# }
# ```
# ```
# {
#     'index': [60, 61, 62, 63, 64],
#     '보험 발생(질병)': ['3종 수술 및 시술', '4종 수술 및 시술', '5종 수술 및 시술', '6종 수술 및 시술', '7종 수술 및 시술'],
#     '보장 횟수': ['수술시술코드당 연간1회한', '수술시술코드당 연간1회한', '수술시술코드당 연간1회한', '수술시술코드당 연간1회한', '수술시술코드당 연간1회한'],
#     '내용 요약': [
#         '3종 수술 및 시술을 받은 경우 가입금액 지급(수술시술코드당 연간1회한). 1회의 입원당 1회의 「수술 및 시술」 또는 1회의 통원당 1회의 「수술 및 시술」에 한하여 보장',
#         '4종 수술 및 시술을 받은 경우 가입금액 지급(수술시술코드당 연간1회한). 1회의 입원당 1회의 「수술 및 시술」 또는 1회의 통원당 1회의 「수술 및 시술」에 한하여 보장',
#         '5종 수술 및 시술을 받은 경우 가입금액 지급(수술시술코드당 연간1회한). 1회의 입원당 1회의 「수술 및 시술」 또는 1회의 통원당 1회의 「수술 및 시술」에 한하여 보장',
#         '6종 수술 및 시술을 받은 경우 가입금액 지급(수술시술코드당 연간1회한). 1회의 입원당 1회의 「수술 및 시술」 또는 1회의 통원당 1회의 「수술 및 시술」에 한하여 보장',
#         '7종 수술 및 시술을 받은 경우 가입금액 지급(수술시술코드당 연간1회한). 1회의 입원당 1회의 「수술 및 시술」 또는 1회의 통원당 1회의 「수술 및 시술」에 한하여 보장'
#     ]
# }
# ```
# ```
# {
#     'index': [65, 66, 67, 68, 69],
#     '보험 발생(질병)': ['8종 수술 및 시술', '간호·간병통합서비스', '급성심근경색증', '뇌경색증', '화상'],
#     '보장 횟수': ['수술시술코드당 연간1회한', '1일당', '최초 1회한', '최초 1회한', '치료시'],
#     '내용 요약': [
#         '질병의 치료를 직접적인 목적으로 8종 수술 및 시술을 받은 경우 가입금액 지급. 1회의 입원당 1회의 「수술 및 시술」 또는 1회의 통원당 1회의 「수술 및 시술」에 한하여 보장',
#         '질병으로 1일 이상 입원 시 간호·간병통합서비스 사용 시 가입금액 지급. 180일을 한도로 간호·간병통합서비스 사용 1일당 일당지급',
#         '급성심근경색증 진단 후 혈전용해 치료 시 가입금액 지급. 최초 1회한',
#         '뇌경색증 진단 후 혈전용해 치료 시 가입금액 지급. 최초 1회한',
#         '심재성 2도 이상 화상 수술 시 가입금액 지급'
#     ]
# }
# ```
# ```
# {
#     'index': [70],
#     '보험 발생(질병)': ['화상'],
#     '보장 횟수': ['치료시'],
#     '내용 요약': ['심재성 2도 이상 화상 수술 시 가입금액 지급']
# }
# ```

# %%
gpt_answers = []


for response in gpt_responses:
    try:
        response = response.replace('`', '')
        response = response.replace('\n', '')
        response = response.replace('=', '')
        response = response.replace('python', '')
        response = response.replace("'''", '')
        response = "'''" + response + "'''"


        response = ast.literal_eval(response)
        response = ast.literal_eval(response)
        
        gpt_answers.append(response)
    except (SyntaxError, ValueError) as e:
        print(traceback.print_exc())
        break

# %%
gpt_answers[0].keys()
# Out:
# dict_keys(['index', '보험 발생(질병)', '보장 횟수', '내용 요약'])

# %%
result_df=pd.DataFrame(columns=['index', '보험 발생(질병)', '보장 횟수', '내용 요약'])

for answers in gpt_answers:
    try:
        temp_df = pd.DataFrame(answers)
        result_df = pd.concat([result_df, temp_df], join='inner')
    except ValueError as e:
        print(traceback.print_exc())
        print(answers)
        break

# %%
result_df.head()
# Out:
#   보험 발생(질병) 보장 횟수                                              내용 요약
# 0       간병인   1일당  상해로 1일 이상 입원 시 간병인 사용에 따라 일당 지급. 7만원 미만 50%, 7...
# 1       간병인   1일당  요양병원에서 1일 이상 입원 시 간병인 사용에 따라 가입금액을 매5년마다 10%씩 ...
# 2       간병인   1일당  질병으로 1일 이상 입원 시 간병인 사용에 따라 일당 지급. 7만원 미만 50%, ...
# 3       간병인   1일당  질병으로 요양병원에서 1일 이상 입원 시 간병인 사용에 따라 가입금액을 매5년마다 ...
# 4       간병인   1일당  상해로 1일 이상 입원 시 간병인 사용에 따라 일당 지급. 7만원 미만 50%, 7...

# %%
pd.set_option('display.max_rows', 400)

# %%
result_df = result_df.drop('index', axis=1).reset_index(drop=True)

# %%
data = data.join(result_df)

# %%
data.head()
# Out:
#   유형1   유형2                                    보험 보장 대상  \
# 0  입원  간병인1          (체증형)상해 입원 간병인 사용일당(1일이상)(요양병원 제외)
# 1  입원  간병인1             (체증형)상해 입원 간병인 사용일당(1일이상)(요양병원)
# 2  입원  간병인1          (체증형)질병 입원 간병인 사용일당(1일이상)(요양병원 제외)
# 3  입원  간병인1             (체증형)질병 입원 간병인 사용일당(1일이상)(요양병원)
# 4  입원  간병인2  (체증형,20년후2배)상해 입원 간병인 사용일당(1 일이상)(요양병원 제외)
#
#                                                상세 설명 보장단위    보장금액  월 보험료  \
# 0  상해사고로 병·의원(요양병원 제외) 등에 1일이상 계속 입원하여 치료를 받 으며, ...   1일  150000   7305
# 1  상해사고로 요양병원에 1일이상 계속 입원하여 치료를 받으며, 약관에 정한 간병인을 ...   1일   30000    393
# 2  보험기간 중 질병으로 병·의원(요양병원 제외) 등에 1일이상 계속 입원하여 치료를 ...   1일  150000  25297
# 3  보험기간 중 질병으로 요양병원에 1일이상 계속 입원하여 치료를 받으며, 약관에 정한...   1일   10000   3438
# 4  상해사고로 병·의원(요양병원 제외) 등에 1일이상 계속 입원하여 치료를 받 으며, ...   1일  150000   7695
#
#    기본 보험료  할증 보험료   그룹    보험기간  납입기간(년) 갱신   만기 보험료  보장 대비 납입율 보험 발생(질병)  \
# 0    7305     NaN  NaN  100세만기       20  납  1753200    11.6880       간병인
# 1     393     NaN  NaN  100세만기       20  납    94320     3.1440       간병인
# 2   17265  8032.0  NaN  100세만기       20  납  6071280    40.4752       간병인
# 3    2374  1064.0  NaN  100세만기       20  납   825120    82.5120       간병인
# 4    7695     NaN  NaN  100세만기       20  납  1846800    12.3120       간병인
#
#   보장 횟수                                              내용 요약
# 0   1일당  상해로 1일 이상 입원 시 간병인 사용에 따라 일당 지급. 7만원 미만 50%, 7...
# 1   1일당  요양병원에서 1일 이상 입원 시 간병인 사용에 따라 가입금액을 매5년마다 10%씩 ...
# 2   1일당  질병으로 1일 이상 입원 시 간병인 사용에 따라 일당 지급. 7만원 미만 50%, ...
# 3   1일당  질병으로 요양병원에서 1일 이상 입원 시 간병인 사용에 따라 가입금액을 매5년마다 ...
# 4   1일당  상해로 1일 이상 입원 시 간병인 사용에 따라 일당 지급. 7만원 미만 50%, 7...

# %%
data['보험기간'].value_counts()
# Out:
# 보험기간
# 100세만기    70
# 20년만기      1
# Name: count, dtype: int64

# %%
data[data['보험기간']=='20년만기']
# Out:
#    유형1 유형2    보험 보장 대상                                    상세 설명 보장단위   보장금액  \
# 44  진단   암  유사암진단 납입지원  이 특별약관의 보험기간 중 「기타피부암」,「갑상선암」,「대장점막내...  발생시  66000
#
#     월 보험료  기본 보험료  할증 보험료   그룹   보험기간  납입기간(년) 갱신  만기 보험료  보장 대비 납입율  \
# 44    488     488     NaN  NaN  20년만기       20  납  117120   1.774545
#
#                            보험 발생(질병)  보장 횟수  \
# 44  기타피부암, 갑상선암, 대장점막내암, 제자리암, 경계성종양  차회 이후
#
#                                       내용 요약
# 44  기타피부암, 갑상선암, 대장점막내암, 제자리암, 경계성종양 진단 ...

# %%
data = pd.read_excel('preprocessed_data_txt-sum.xlsx')

# %%
data.columns
# Out:
# Index(['유형1', '유형2', '보험 보장 대상', '상세 설명', '보장단위', '보장금액', '월 보험료', '기본 보험료',
#        '할증 보험료', '그룹', '보험기간', '납입기간(년)', '갱신', '만기 보험료', '보장 대비 납입율',
#        '보험 발생(질병)', '보장 횟수', '내용 요약'],
#       dtype='object')

# %%
data.to_excel('preprocessed_data_txt-sum.xlsx', index=False)
