# %%
import pandas as pd
from ydata_profiling import ProfileReport

import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', 40)
# Out:
# C:\Users\kyeul\AppData\Local\Temp\ipykernel_23088\175995752.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
def data_summary(df):
    """
    주어진 DataFrame에서 각 열의 요약 통계를 계산하고 결과를 새로운 DataFrame으로 반환한다.

    Parameters:
        df (DataFrame): 분석할 데이터를 포함한 pandas DataFrame.

    Returns:
        DataFrame: 각 열의 데이터 타입, 개수, 고유값 개수, 결측치 개수, 결측치 비율, 고유값을 포함한 요약 정보.
    """
    obs = df.shape[0]
    types = df.dtypes
    counts = df.apply(lambda x: x.count())
    uniques = df.apply(lambda x: [x.unique()]).T.squeeze()
    nulls = df.apply(lambda x: x.isnull().sum())
    distincts = df.apply(lambda x: x.unique().shape[0])
    missing_ratio = (df.isnull().sum() / obs)*100
    
    print("Data shape: ", df.shape)

    cols = ['Types', 'Counts', 'Distincts', 'Nulls', 'Missing_ratio', 'Uniques']
    structure = pd.concat([types, counts, distincts, nulls, missing_ratio, uniques], axis=1, sort=True)

    structure.columns = cols

    print("================================================")
    print("Data types: ")
    print(structure['Types'].value_counts())
    print("================================================")
    print("\n\n")

    return structure

# %%
data = pd.read_excel('보험데이터_체증형_통합.xlsx')

# %%
data_summary(data)
# Out:
# Data shape:  (71, 11)
# ================================================
# Data types:
# Types
# object     7
# int64      3
# float64    1
# Name: count, dtype: int64
# ================================================
#              Types  Counts  Distincts  Nulls  Missing_ratio  \
# 그룹          object      20          7     51      71.830986
# 기본 보험료       int64      71         59      0       0.000000
# 납입기간/보험기간   object      71          5      0       0.000000
# 보장금액         int64      71         23      0       0.000000
# 보장단위        object      71          4      0       0.000000
# 보험 보장 대상    object      71         71      0       0.000000
# 상세 설명       object      71         71      0       0.000000
# 유형1         object      71          6      0       0.000000
# 유형2         object      71         14      0       0.000000
# 총 보험료        int64      71         59      0       0.000000
# 할증 보험료     float64      17         14     54      76.056338
#
#                                            Uniques
# 그룹                         [nan, f, b, c, d, e, a]
# 기본 보험료     [7305, 393, 17265, 2374, 7695, 396, ...
# 납입기간/보험기간  [20년납 100세만기, 20년납\n100세만기, 20년갱신 10...
# 보장금액       [150000, 30000, 10000, 100000000, 20...
# 보장단위                       [1일, 발생시, 최초 1회, 연간 1회]
# 보험 보장 대상   [(체증형)상해 입원 간병인 사용일당(1일이상)(요양병원 제외),...
# 상세 설명      [상해사고로 병·의원(요양병원 제외) 등에 1일이상 계속 입원하여...
# 유형1                 [입원, 생활, 수술, 진단, 간병/사망, 장해/장애]
# 유형2        [간병인1, 간병인2, 일상배상, 로봇수술, 질병, 골절, 갑상선...
# 총 보험료      [7305, 393, 25297, 3438, 7695, 396, ...
# 할증 보험료     [nan, 8032.0, 1064.0, 8493.0, 3207.0...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   유형1        71 non-null     object
#  1   유형2        71 non-null     object
#  2   보험 보장 대상   71 non-null     object
#  3   상세 설명      71 non-null     object
#  4   보장단위       71 non-null     object
#  5   보장금액       71 non-null     int64
#  6   총 보험료      71 non-null     int64
#  7   기본 보험료     71 non-null     int64
#  8   할증 보험료     17 non-null     float64
#  9   납입기간/보험기간  71 non-null     object
#  10  그룹         20 non-null     object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 6.2+ KB

# %%
data.head()
# Out:
#   유형1   유형2                                 보험 보장 대상  \
# 0  입원  간병인1       (체증형)상해 입원 간병인 사용일당(1일이상)(요양병원 제외)
# 1  입원  간병인1          (체증형)상해 입원 간병인 사용일당(1일이상)(요양병원)
# 2  입원  간병인1       (체증형)질병 입원 간병인 사용일당(1일이상)(요양병원 제외)
# 3  입원  간병인1          (체증형)질병 입원 간병인 사용일당(1일이상)(요양병원)
# 4  입원  간병인2  (체증형,20년후2배)상해 입원 간병인 사용일당(1 일이상)(요양...
#
#                                      상세 설명 보장단위    보장금액  총 보험료  기본 보험료  \
# 0  상해사고로 병·의원(요양병원 제외) 등에 1일이상 계속 입원하여 ...   1일  150000   7305    7305
# 1  상해사고로 요양병원에 1일이상 계속 입원하여 치료를 받으며, 약관...   1일   30000    393     393
# 2  보험기간 중 질병으로 병·의원(요양병원 제외) 등에 1일이상 계속...   1일  150000  25297   17265
# 3  보험기간 중 질병으로 요양병원에 1일이상 계속 입원하여 치료를 받...   1일   10000   3438    2374
# 4  상해사고로 병·의원(요양병원 제외) 등에 1일이상 계속 입원하여 ...   1일  150000   7695    7695
#
#    할증 보험료     납입기간/보험기간   그룹
# 0     NaN   20년납 100세만기  NaN
# 1     NaN   20년납 100세만기  NaN
# 2  8032.0   20년납 100세만기  NaN
# 3  1064.0   20년납 100세만기  NaN
# 4     NaN  20년납\n100세만기  NaN

# %%
# help(ProfileReport)

# %%
# profile = ProfileReport(data, title="Profiling Report")
# profile

# %% [markdown]
# ## 데이터 전처리

# %%
def split_data(x):
    """납입기간과 보험기간을 분리"""
    if ' ' in x:
        period = x.split(' ')[0]
        guarantee = x.split(' ')[1]
    elif '\n' in x:
        period = x.split('\n')[0]
        guarantee = x.split('\n')[1]

    return [period, guarantee]

# %%
data[['납입기간', '보험기간']] = data['납입기간/보험기간'].apply(lambda x: pd.Series(split_data(x)))

# %%
data.drop('납입기간/보험기간', inplace=True, axis=1)
data.sample(10)
# Out:
#    유형1   유형2                                 보험 보장 대상  \
# 5   입원  간병인2  (체증형,20년후2배)상해 입원 간병인 사용일당(1 일이상)(요양병원)
# 4   입원  간병인2  (체증형,20년후2배)상해 입원 간병인 사용일당(1 일이상)(요양...
# 65  수술    질병                          질병 8종 수술비(시술포함)
# 29  수술    상해                          상해 1종 수술비(시술포함)
# 62  수술    질병                          질병 5종 수술비(시술포함)
# 57  진단    화상                             중대 화상·부식 진단비
# 59  수술    질병                          질병 2종 수술비(시술포함)
# 0   입원  간병인1       (체증형)상해 입원 간병인 사용일당(1일이상)(요양병원 제외)
# 10  수술  로봇수술                      [갱신형] 특정암 다빈치로봇 수술비
# 70  진단    화상                                   화상 진단비
#
#                                       상세 설명   보장단위      보장금액  총 보험료  기본 보험료  \
# 5   상해사고로 요양병원에 1일이상 계속 입원하여 치료를 받으며, 약관...     1일     30000    396     396
# 4   상해사고로 병·의원(요양병원 제외) 등에 1일이상 계속 입원하여 ...     1일    150000   7695    7695
# 65  보험기간 중 질병의 치료를 직접적인 목적으로 약관에서 정한 8종 ...  연간 1회  15000000   5056    3410
# 29  보험기간 중 상해의 치료를 직접적인 목적으로 약관에서 정한 1종 ...  연간 1회    300000    546     546
# 62  보험기간 중 질병의 치료를 직접적인 목적으로 약관에서 정한 5종 ...  연간 1회   3000000   5058    3411
# 57  상해사고로 신체 표면적으로 최소 20%이상의 3도 화상 또는 부식...  최초 1회  10000000     51      51
# 59  보험기간 중 질병의 치료를 직접적인 목적으로 약관에서 정한 2종 ...  연간 1회    300000   3646    2453
# 0   상해사고로 병·의원(요양병원 제외) 등에 1일이상 계속 입원하여 ...     1일    150000   7305    7305
# 10  보장개시일 이후 특정암(갑상선암, 전립선암)으로 진단 확정되고 그...  최초 1회  10000000    200     200
# 70  상해사고로 심재성 2도 이상에 해당하는 화상으로 진단 확정된 경우...    발생시    100000     76      76
#
#     할증 보험료   그룹   납입기간    보험기간
# 5      NaN  NaN   20년납  100세만기
# 4      NaN  NaN   20년납  100세만기
# 65  1646.0    e   20년납  100세만기
# 29     NaN    b   20년납  100세만기
# 62  1647.0    e   20년납  100세만기
# 57     NaN  NaN   20년납  100세만기
# 59  1193.0    d   20년납  100세만기
# 0      NaN  NaN   20년납  100세만기
# 10     NaN  NaN  10년갱신  100세만기
# 70     NaN  NaN   20년납  100세만기

# %%
data['보험기간'].value_counts()
# Out:
# 보험기간
# 100세만기    70
# 20년만기      1
# Name: count, dtype: int64

# %%
data[data['보험기간']=='20년만기']
# Out:
#    유형1 유형2    보험 보장 대상                                    상세 설명 보장단위   보장금액  \
# 44  진단   암  유사암진단 납입지원  이 특별약관의 보험기간 중 「기타피부암」,「갑상선암」,「대장점막내...  발생시  66000
#
#     총 보험료  기본 보험료  할증 보험료   그룹  납입기간   보험기간
# 44    488     488     NaN  NaN  20년납  20년만기

# %%
# ['보험기간', '갱신']으로 나누기
data[['납입기간(년)', '갱신']] = data['납입기간'].str.split('년', expand=True)
data.drop('납입기간', inplace=True, axis=True)
data.sample(10)
# Out:
#       유형1   유형2                                 보험 보장 대상  \
# 42     진단     암                암(기타피부암 및 갑상선암 제외) 치료비 지원
# 36     수술    상해                          상해 8종 수술비(시술포함)
# 69     수술    화상                                   화상 수술비
# 40  장해/장애    상해                          상해 후유장해(3~100%)
# 11     생활  일상배상                 [공제][갱신형] 가족 일상생활중 배상책임Ⅱ
# 0      입원  간병인1       (체증형)상해 입원 간병인 사용일당(1일이상)(요양병원 제외)
# 45     진단  응급의료                   응급의료 아나필락시스 진단비(연간1회한)
# 67     수술  심근경색                         혈전용해치료비(급성심근경색증)
# 38  간병/사망    상해                                    상해 사망
# 6      입원  간병인2  (체증형,20년후2배)질병 입원 간병인 사용일당(1 일이상)(요양...
#
#                                       상세 설명   보장단위      보장금액  총 보험료  기본 보험료  \
# 42  보장개시일 이후 암으로 진단 확정된 경우 가입금액 지급(최초 1회...  최초 1회    100000    115     115
# 36  보험기간 중 상해의 치료를 직접적인 목적으로 약관에서 정한 8종 ...  연간 1회  25000000    266     266
# 69  상해사고로 심재성 2도 이상에 해당하는 화상으로 진단 확정 후 그...    발생시    300000     11      11
# 40           상해사고로 후유장해가 발생한 경우 가입금액 한도로 지급    발생시  20000000   1000    1000
# 11  ※ 1사고당 자기부담금 : 대인 없음, 대물누수사고 50만원, 대...    발생시    500000      0       0
# 0   상해사고로 병·의원(요양병원 제외) 등에 1일이상 계속 입원하여 ...     1일    150000   7305    7305
# 45  보험기간 중 응급실에 내원하여 약관에서 정한 아나필락시스(anap...  연간 1회   2000000    200     200
# 67  보험기간 중 약관에서 정한 급성심근경색증으로 진단 확정되고, 그 ...  최초 1회  10000000    445     445
# 38                     상해사고로 사망한 경우 가입금액 지급    발생시  50000000   2550    2550
# 6   보험기간 중 질병으로 병·의원(요양병원 제외) 등에 1일이상 계속...     1일    150000  26733   18240
#
#     할증 보험료   그룹    보험기간 납입기간(년)  갱신
# 42     NaN  NaN  100세만기      20   납
# 36     NaN    c  100세만기      20   납
# 69     NaN  NaN  100세만기      20   납
# 40     NaN  NaN  100세만기      20   납
# 11     NaN  NaN  100세만기      20  갱신
# 0      NaN  NaN  100세만기      20   납
# 45     NaN  NaN  100세만기      20   납
# 67     NaN    a  100세만기      20   납
# 38     NaN  NaN  100세만기      20   납
# 6   8493.0  NaN  100세만기      20   납

# %%
data[data['갱신']!='납']
# Out:
#    유형1   유형2                   보험 보장 대상  \
# 8   생활  일상배상       [갱신형] 가족 일상생활중 배상책임Ⅱ
# 9   수술  로봇수술  [갱신형] 암(특정암 제외) 다빈치로봇 수술비
# 10  수술  로봇수술        [갱신형] 특정암 다빈치로봇 수술비
# 11  생활  일상배상   [공제][갱신형] 가족 일상생활중 배상책임Ⅱ
#
#                                       상세 설명   보장단위       보장금액  총 보험료  기본 보험료  \
# 8   본인 및 약관에 정한 가족의 일상생활 및 보험증권에 기재된 주택의...    발생시  100000000   1154    1154
# 9   보장개시일 이후 암(특정암 제외)으로 진단 확정되고 그 암(특정암...  최초 1회   20000000   1120    1120
# 10  보장개시일 이후 특정암(갑상선암, 전립선암)으로 진단 확정되고 그...  최초 1회   10000000    200     200
# 11  ※ 1사고당 자기부담금 : 대인 없음, 대물누수사고 50만원, 대...    발생시     500000      0       0
#
#     할증 보험료   그룹    보험기간 납입기간(년)  갱신
# 8      NaN  NaN  100세만기      20  갱신
# 9      NaN  NaN  100세만기      10  갱신
# 10     NaN  NaN  100세만기      10  갱신
# 11     NaN  NaN  100세만기      20  갱신

# %%
data.rename(columns={'납/갱':'납입/갱신'}, inplace=True)

# %%
# 항목별 전체 납입액 구하기
data.rename(columns={'총 보험료':'월 보험료'}, inplace=True)

# %%
123 * 20 * 12
# Out:
# 29520

# %%
data['만기 보험료'] = data['월 보험료'] * data['납입기간(년)'].astype('int') * 12
data.head(10)
# Out:
#   유형1   유형2                                 보험 보장 대상  \
# 0  입원  간병인1       (체증형)상해 입원 간병인 사용일당(1일이상)(요양병원 제외)
# 1  입원  간병인1          (체증형)상해 입원 간병인 사용일당(1일이상)(요양병원)
# 2  입원  간병인1       (체증형)질병 입원 간병인 사용일당(1일이상)(요양병원 제외)
# 3  입원  간병인1          (체증형)질병 입원 간병인 사용일당(1일이상)(요양병원)
# 4  입원  간병인2  (체증형,20년후2배)상해 입원 간병인 사용일당(1 일이상)(요양...
# 5  입원  간병인2  (체증형,20년후2배)상해 입원 간병인 사용일당(1 일이상)(요양병원)
# 6  입원  간병인2  (체증형,20년후2배)질병 입원 간병인 사용일당(1 일이상)(요양...
# 7  입원  간병인2  (체증형,20년후2배)질병 입원 간병인 사용일당(1 일이상)(요양병원)
# 8  생활  일상배상                     [갱신형] 가족 일상생활중 배상책임Ⅱ
# 9  수술  로봇수술                [갱신형] 암(특정암 제외) 다빈치로봇 수술비
#
#                                      상세 설명   보장단위       보장금액  월 보험료  기본 보험료  \
# 0  상해사고로 병·의원(요양병원 제외) 등에 1일이상 계속 입원하여 ...     1일     150000   7305    7305
# 1  상해사고로 요양병원에 1일이상 계속 입원하여 치료를 받으며, 약관...     1일      30000    393     393
# 2  보험기간 중 질병으로 병·의원(요양병원 제외) 등에 1일이상 계속...     1일     150000  25297   17265
# 3  보험기간 중 질병으로 요양병원에 1일이상 계속 입원하여 치료를 받...     1일      10000   3438    2374
# 4  상해사고로 병·의원(요양병원 제외) 등에 1일이상 계속 입원하여 ...     1일     150000   7695    7695
# 5  상해사고로 요양병원에 1일이상 계속 입원하여 치료를 받으며, 약관...     1일      30000    396     396
# 6  보험기간 중 질병으로 병·의원(요양병원 제외) 등에 1일이상 계속...     1일     150000  26733   18240
# 7  보험기간 중 질병으로 요양병원에 1일이상 계속 입원하여 치료를 받...     1일      30000  10338    7131
# 8  본인 및 약관에 정한 가족의 일상생활 및 보험증권에 기재된 주택의...    발생시  100000000   1154    1154
# 9  보장개시일 이후 암(특정암 제외)으로 진단 확정되고 그 암(특정암...  최초 1회   20000000   1120    1120
#
#    할증 보험료   그룹    보험기간 납입기간(년)  갱신   만기 보험료
# 0     NaN  NaN  100세만기      20   납  1753200
# 1     NaN  NaN  100세만기      20   납    94320
# 2  8032.0  NaN  100세만기      20   납  6071280
# 3  1064.0  NaN  100세만기      20   납   825120
# 4     NaN  NaN  100세만기      20   납  1846800
# 5     NaN  NaN  100세만기      20   납    95040
# 6  8493.0  NaN  100세만기      20   납  6415920
# 7  3207.0  NaN  100세만기      20   납  2481120
# 8     NaN  NaN  100세만기      20  갱신   276960
# 9     NaN  NaN  100세만기      10  갱신   134400

# %%
# 보장 받는 것에 비해 얼마나 많이 낼까?
data['보장 대비 납입율'] = data['만기 보험료'] / data['보장금액']

# %%
# 전처리 후 data summary
data_summary(data)
# Out:
# Data shape:  (71, 15)
# ================================================
# Data types:
# Types
# object     9
# int64      4
# float64    2
# Name: count, dtype: int64
# ================================================
#              Types  Counts  Distincts  Nulls  Missing_ratio  \
# 갱신          object      71          2      0       0.000000
# 그룹          object      20          7     51      71.830986
# 기본 보험료       int64      71         59      0       0.000000
# 납입기간(년)     object      71          2      0       0.000000
# 만기 보험료       int64      71         60      0       0.000000
# 보장 대비 납입율  float64      71         65      0       0.000000
# 보장금액         int64      71         23      0       0.000000
# 보장단위        object      71          4      0       0.000000
# 보험 보장 대상    object      71         71      0       0.000000
# 보험기간        object      71          2      0       0.000000
# 상세 설명       object      71         71      0       0.000000
# 월 보험료        int64      71         59      0       0.000000
# 유형1         object      71          6      0       0.000000
# 유형2         object      71         14      0       0.000000
# 할증 보험료     float64      17         14     54      76.056338
#
#                                            Uniques
# 갱신                                         [납, 갱신]
# 그룹                         [nan, f, b, c, d, e, a]
# 기본 보험료     [7305, 393, 17265, 2374, 7695, 396, ...
# 납입기간(년)                                   [20, 10]
# 만기 보험료     [1753200, 94320, 6071280, 825120, 18...
# 보장 대비 납입율  [11.688, 3.144, 40.4752, 82.512, 12....
# 보장금액       [150000, 30000, 10000, 100000000, 20...
# 보장단위                       [1일, 발생시, 최초 1회, 연간 1회]
# 보험 보장 대상   [(체증형)상해 입원 간병인 사용일당(1일이상)(요양병원 제외),...
# 보험기간                               [100세만기, 20년만기]
# 상세 설명      [상해사고로 병·의원(요양병원 제외) 등에 1일이상 계속 입원하여...
# 월 보험료      [7305, 393, 25297, 3438, 7695, 396, ...
# 유형1                 [입원, 생활, 수술, 진단, 간병/사망, 장해/장애]
# 유형2        [간병인1, 간병인2, 일상배상, 로봇수술, 질병, 골절, 갑상선...
# 할증 보험료     [nan, 8032.0, 1064.0, 8493.0, 3207.0...

# %% [markdown]
# ## 유형별 분석

# %%
data['유형1'].value_counts()
# Out:
# 유형1
# 수술       33
# 진단       24
# 입원       10
# 생활        2
# 간병/사망     1
# 장해/장애     1
# Name: count, dtype: int64

# %%
display(data['유형2'].value_counts())
# Out:
# 유형2
# 질병      16
# 암       15
# 상해      14
# 간병인1     4
# 간병인2     4
# 골절       4
# 화상       3
# 일상배상     2
# 로봇수술     2
# 갑상선      2
# 심근경색     2
# 응급의료     1
# 인공관절     1
# 간호간병     1
# Name: count, dtype: int64

# %%
# 만기 보험료 순 항목
pd.set_option('display.max_colwidth', 50)
sorted_total = data.sort_values('만기 보험료', ascending=False)

# %%
sorted_total[sorted_total['보험 보장 대상'].str.endswith('(요양병원)')][['보험 보장 대상', '보장금액', '월 보험료', '만기 보험료']]
# Out:
#                                   보험 보장 대상   보장금액  월 보험료   만기 보험료
# 7  (체증형,20년후2배)질병 입원 간병인 사용일당(1 일이상)(요양병원)  30000  10338  2481120
# 3          (체증형)질병 입원 간병인 사용일당(1일이상)(요양병원)  10000   3438   825120
# 5  (체증형,20년후2배)상해 입원 간병인 사용일당(1 일이상)(요양병원)  30000    396    95040
# 1          (체증형)상해 입원 간병인 사용일당(1일이상)(요양병원)  30000    393    94320

# %%
# 보장 대비 납입율 
data[data['보장단위']=='발생시'].sort_values('보장 대비 납입율', ascending=False)
# Out:
#       유형1   유형2                  보험 보장 대상  \
# 17     수술    질병       111대질병 수술비(62대생활질병)
# 23     진단    골절                    골절 진단비
# 44     진단     암                유사암진단 납입지원
# 24     진단    골절  골절 진단비(치아파절(깨짐, 부러짐) 제외)
# 37     수술    상해                 상해 골절 수술비
# 27     진단    골절           깁스 치료비(부목치료 제외)
# 70     진단    화상                    화상 진단비
# 13     수술    질병       111대질병 수술비(22대주요질병)
# 14     수술    질병        111대질병 수술비(3대주요질병)
# 15     수술    질병      111대질병 수술비(5대주요기관관혈)
# 12     수술    질병       111대질병 수술비(19대생활질병)
# 16     수술    질병     111대질병 수술비(5대주요기관비관혈)
# 20     수술    골절                  5대골절 수술비
# 41     수술    상해              아킬레스힘줄손상 수술비
# 38  간병/사망    상해                     상해 사망
# 40  장해/장애    상해           상해 후유장해(3~100%)
# 69     수술    화상                    화상 수술비
# 8      생활  일상배상      [갱신형] 가족 일상생활중 배상책임Ⅱ
# 11     생활  일상배상  [공제][갱신형] 가족 일상생활중 배상책임Ⅱ
#
#                                                 상세 설명 보장단위       보장금액  월 보험료  \
# 17  보험기간 중 약관에 정한 62대 생활질병으로 진단 확정되고 그 치료를 직접 적인 목...  발생시     200000   3419
# 23                 상해사고로 약관에 정한 골절로 진단 확정된 경우 가입금액 지급  발생시     100000    898
# 44  이 특별약관의 보험기간 중 「기타피부암」,「갑상선암」,「대장점막내암」,「제자 리암」...  발생시      66000    488
# 24  상해사고로 약관에 정한 골절(치아파절(깨짐, 부러짐) 제외)로 진단 확정된 경우 가...  발생시     200000   1140
# 37                   상해사고로 약관에 정한 골절로 수술받은 경우 가입금액 지급  발생시     200000    372
# 27  보험기간 중 상해 또는 질병으로 약관에 정한 깁스치료를 받은 경우 가입금 액 지급\...  발생시     100000    123
# 70      상해사고로 심재성 2도 이상에 해당하는 화상으로 진단 확정된 경우 가입금 액 지급  발생시     100000     76
# 13  보험기간 중 약관에 정한 22대 주요질병으로 진단 확정되고 그 치료를 직접 적인 목...  발생시    1000000    704
# 14  보험기간 중 약관에 정한 갑상선질환, 고혈압 및 당뇨병으로 진단 확정되고 그 치료를...  발생시     500000    275
# 15  보험기간 중 약관에 정한 뇌질환, 심질환, 간·췌장질환 및 폐질환으로 진단 확정되고...  발생시   20000000   7320
# 12  보험기간 중 약관에 정한 19대 생활질병으로 진단 확정되고 그 치료를 직접 적인 목...  발생시     100000     22
# 16  보험기간 중 약관에 정한 뇌질환, 심질환, 간·췌장질환 및 폐질환으로 진단 확정되고...  발생시   10000000   2110
# 20                 상해사고로 약관에 정한 5대골절로 수술받은 경우 가입금액 지급  발생시     500000     80
# 41   상해사고로 약관에 정한 아킬레스힘줄손상으로 진단확정되어 수술을 받은 경우 가입금액 지급  발생시    1000000     60
# 38                               상해사고로 사망한 경우 가입금액 지급  발생시   50000000   2550
# 40                     상해사고로 후유장해가 발생한 경우 가입금액 한도로 지급  발생시   20000000   1000
# 69  상해사고로 심재성 2도 이상에 해당하는 화상으로 진단 확정 후 그 치료를 직접적인 ...  발생시     300000     11
# 8   본인 및 약관에 정한 가족의 일상생활 및 보험증권에 기재된 주택의 소유, 사용 또는...  발생시  100000000   1154
# 11    ※ 1사고당 자기부담금 : 대인 없음, 대물누수사고 50만원, 대물누수사고외 20만원  발생시     500000      0
#
#     기본 보험료  할증 보험료   그룹    보험기간 납입기간(년)  갱신   만기 보험료  보장 대비 납입율
# 17    2322 1097.00  NaN  100세만기      20   납   820560       4.10
# 23     898     NaN  NaN  100세만기      20   납   215520       2.16
# 44     488     NaN  NaN   20년만기      20   납   117120       1.77
# 24    1140     NaN  NaN  100세만기      20   납   273600       1.37
# 37     372     NaN  NaN  100세만기      20   납    89280       0.45
# 27     123     NaN  NaN  100세만기      20   납    29520       0.30
# 70      76     NaN  NaN  100세만기      20   납    18240       0.18
# 13     482  222.00  NaN  100세만기      20   납   168960       0.17
# 14     188   87.00  NaN  100세만기      20   납    66000       0.13
# 15    7320     NaN  NaN  100세만기      20   납  1756800       0.09
# 12      15    7.00  NaN  100세만기      20   납     5280       0.05
# 16    2110     NaN  NaN  100세만기      20   납   506400       0.05
# 20      80     NaN  NaN  100세만기      20   납    19200       0.04
# 41      60     NaN  NaN  100세만기      20   납    14400       0.01
# 38    2550     NaN  NaN  100세만기      20   납   612000       0.01
# 40    1000     NaN  NaN  100세만기      20   납   240000       0.01
# 69      11     NaN  NaN  100세만기      20   납     2640       0.01
# 8     1154     NaN  NaN  100세만기      20  갱신   276960       0.00
# 11       0     NaN  NaN  100세만기      20  갱신        0       0.00

# %%
pd.options.display.float_format = '{:.2f}'.format
display(data.groupby('보장단위')[['보장금액', '월 보험료', '만기 보험료']].mean())
display(data.groupby('보장단위')[['보장금액', '월 보험료', '만기 보험료']].std())
# Out:
#              보장금액   월 보험료     만기 보험료
# 보장단위
# 1일       84000.00 8582.50 2059800.00
# 발생시   10782421.05 1147.47  275393.68
# 연간 1회  6593548.39 2165.13  519630.97
# 최초 1회  5981818.18  341.91   67658.18
#              보장금액   월 보험료     만기 보험료
# 보장단위
# 1일       59665.74 9786.38 2348730.36
# 발생시   24937759.06 1773.67  425680.96
# 연간 1회  6012566.59 2982.72  715853.70
# 최초 1회  6462788.59  338.50   58135.95

# %%
data[data['보장단위']=='최초 1회'].sort_values('보장 대비 납입율', ascending=False)
# Out:
#    유형1   유형2                   보험 보장 대상  \
# 28  진단    상해                보험료 납입면제대상Ⅱ
# 42  진단     암  암(기타피부암 및 갑상선암 제외) 치료비 지원
# 46  수술  인공관절                 인공관절치환 수술비
# 21  진단   갑상선               갑상선기능저하증 진단비
# 22  진단   갑상선               갑상선기능항진증 치료비
# 26  진단     암        기타피부암 및 갑상선암 치료비 지원
# 67  수술  심근경색           혈전용해치료비(급성심근경색증)
# 68  수술  심근경색              혈전용해치료비(뇌경색증)
# 9   수술  로봇수술  [갱신형] 암(특정암 제외) 다빈치로봇 수술비
# 10  수술  로봇수술        [갱신형] 특정암 다빈치로봇 수술비
# 57  진단    화상               중대 화상·부식 진단비
#
#                                                 상세 설명   보장단위      보장금액  월 보험료  \
# 28  보장개시일 이후 상해사고로 80%이상 후유장해가 발생하거나 약관에서 정 한 암, 뇌...  최초 1회    100000    168
# 42  보장개시일 이후 암으로 진단 확정된 경우 가입금액 지급(최초 1회한)\n※ 암의 보...  최초 1회    100000    115
# 46  보험기간 중 상해 또는 질병으로 약관에 정한 인공관절치환 수술을 받은 경우 가입금액...  최초 1회   2500000    775
# 21  보험기간 중 약관에서 정한 「갑상선기능저하증」으로 진단 확정된 경우 가입 금액 지급...  최초 1회   1000000    170
# 22  보험기간 중 약관에서 정한 「갑상선기능항진증」으로 진단 확정되고 「갑상선 기능항진증...  최초 1회   2000000    260
# 26  보장개시일 이후 기타피부암 또는 갑상선암으로 진단 확정된 경우 가입금액 지급(최초 ...  최초 1회    100000     12
# 67  보험기간 중 약관에서 정한 급성심근경색증으로 진단 확정되고, 그 치료를 직접적인 목...  최초 1회  10000000    445
# 68  보험기간 중 약관에서 정한 뇌경색증으로 진단 확정되고, 그 치료를 직접적 인 목적으...  최초 1회  10000000    445
# 9   보장개시일 이후 암(특정암 제외)으로 진단 확정되고 그 암(특정암 제외)의 직접적인...  최초 1회  20000000   1120
# 10  보장개시일 이후 특정암(갑상선암, 전립선암)으로 진단 확정되고 그 특정암 의 직접적...  최초 1회  10000000    200
# 57  상해사고로 신체 표면적으로 최소 20%이상의 3도 화상 또는 부식(화학약 품 등에 ...  최초 1회  10000000     51
#
#     기본 보험료  할증 보험료   그룹    보험기간 납입기간(년)  갱신  만기 보험료  보장 대비 납입율
# 28     168     NaN  NaN  100세만기      20   납   40320       0.40
# 42     115     NaN  NaN  100세만기      20   납   27600       0.28
# 46     775     NaN  NaN  100세만기      20   납  186000       0.07
# 21     170     NaN  NaN  100세만기      20   납   40800       0.04
# 22     260     NaN  NaN  100세만기      20   납   62400       0.03
# 26      12     NaN  NaN  100세만기      20   납    2880       0.03
# 67     445     NaN    a  100세만기      20   납  106800       0.01
# 68     445     NaN    a  100세만기      20   납  106800       0.01
# 9     1120     NaN  NaN  100세만기      10  갱신  134400       0.01
# 10     200     NaN  NaN  100세만기      10  갱신   24000       0.00
# 57      51     NaN  NaN  100세만기      20   납   12240       0.00

# %% [markdown]
# ## Text Summarization

# %%
import pandas as pd

import ast
import re
import traceback

from ChatGPT_API import request_openai

# %%
data = pd.read_excel('preprocessed_data.xlsx')
# data.head()

# %%
# 배치 프로세싱을 어떻게 진행할 것인가. 하나의 qeury에 여러 메시지를 담아야하고, 그 결과를 분리해서 받을 수 있어야 한다. 
# 그렇다면 문장 요약에서 내가 얻고 싶은 정보는 무엇일까? 
# 1. 어떤 병을 대상으로 한 보험인지. 사실 이거면 된다. 보장 내용은 내가 수작업으로 했으니까.

# %%
N_BATCH = 5

# %%
data_list = data['상세 설명'].to_list()

# 예시 데이터, '상세 설명' 키에 여러 상세 내용이 리스트로 저장되어 있다고 가정
temp = {
    '상세 설명': [f'{i}' for i in data_list]  # 1부터 71까지의 상세 내용 예시
}

# 문서 내용을 담을 빈 문자열 초기화
contents = []

doc_index = 0
# 10개씩 상세 설명을 문서 내용에 포맷팅하여 추가
for i in range(0, len(data_list), N_BATCH):
    
    content = ''

    chunk = temp['상세 설명'][i:i+N_BATCH]
    for detail in chunk:
        content += f"""
        index: {doc_index}
        <문서 내용>
        {detail}

        """
        doc_index += 1
    
    contents.append(content)

# %%
gpt_responses = []

for ducument_content in contents:
    result = request_openai(ducument_content)
    gpt_responses.append(result)

# %%
for i in gpt_responses:
    print(i)
# Out:
# ```
# {
#     'index': [0, 1, 2, 3, 4],
#     '보험 발생(질병)': ['간병인', '간병인', '간병인', '간병인', '간병인'],
#     '보장 횟수': ['1일당', '1일당', '1일당', '1일당', '1일당']
# }
# ```
# '''
# {'index': [5, 6, 7, 8, 9], '보험 발생(질병)': ['간병인', '간병인', '간병인', '대인, 대물의 손해', '암(특정암 제외)'], '보장 횟수': ['가입후 20년 미만 시', '1일당', '가입후 20년 미만 시', '1사고당', '최초 1회한']}
# '''
# '''
# {'index': [10, 11, 12, 13, 14], '보험 발생(질병)': ['갑상선암, 전립선암', '사고', '19대 생활질병', '22대 주요질병', '갑상선질환, 고혈압 및 당뇨병'], '보장 횟수': ['최초 1회', '1사고당', '수술당 1회', '수술당 1회', '수술당 1회']}
# '''
# '''
# {'index': [15, 16, 17, 18, 19], '보험 발생(질병)': ['뇌질환, 심질환, 간·췌장질환 및 폐질환', '뇌질환, 심질환, 간·췌장질환 및 폐질환', '62대 생활질병', '요실금', '선천성이상 질병'], '보장 횟수': ['수술당 1회', '수술당 1회', '수술당 1회', '연간 1회한', '연간 1회한']}
# '''
# ```
# {
#     'index': [20, 21, 22, 23, 24],
#     '보험 발생(질병)': ['5대골절 수술', '갑상선기능저하증', '갑상선기능항진증', '골절', '골절(치아파절)'],
#     '보장 횟수': ['수술받은 경우', '최초 1회', '최초 1회', '진단 확정된 경우', '진단 확정된 경우']
# }
# ```
#
# '''
# {'index': [25, 26, 27, 28, 29], '보험 발생(질병)': ['기타피부암, 갑상선암', '기타피부암, 갑상선암', '깁스치료', '암, 뇌졸중, 급성심근경색증, 중대 화상·부식, 뇌·내장손상 수술', '상해'], '보장 횟수': ['연간 1회한', '최초 1회한', '치료시', '최초 1회한', '수술시술코드당 연간1회한']}
# '''
#
#         '''
#         {'index': [30, 31, 32, 33, 34], '보험 발생(질병)': ['2종 수술 및 시술', '3종 수술 및 시술', '4종 수술 및 시술', '5종 수술 및 시술', '6종 수술 및 시술'], '보장 횟수': ['수술시술코드당 연간1회한', '수술시술코드당 연간1회한', '수술시술코드당 연간1회한', '수술시술코드당 연간1회한', '수술시술코드당 연간1회한']}
#         '''
#         '''
# '''
# {'index': [35, 36, 37, 38, 39], '보험 발생(질병)': ['상해의 치료', '상해의 치료', '골절', '사망', '간호·간병통합서비스'], '보장 횟수': ['수술시술코드당 연간1회한', '수술시술코드당 연간1회한', '수술받은 경우', '1회', '1일당']}
# '''
#
#         '''
#         {'index': [40, 41, 42, 43, 44], '보험 발생(질병)': ['후유장해', '아킬레스힘줄손상', '암', '암(기타피부암 및 갑상선암 제외)', '기타피부암, 갑상선암, 대장점막내암, 제자리암, 경계성종양'], '보장 횟수': ['한도로', '수술받은 경우', '최초 1회', '연간 1회한', '차회 이후 이 계약의 보험료 납 입시마다']}
#         '''
#
# '''
# {'index': [45, 46, 47, 48, 49], '보험 발생(질병)': ['아나필락시스', '인공관절치환', '암, 기타피부암 또는 갑상선암', '암, 기타피부암 또는 갑상선암', '암, 기타피부암 또는 갑상선암'], '보장 횟수': ['연간 1회한', '최초 1회한 지급', '연간 1회한', '연간 1회한', '연간 1회한']}
# '''
# ```python
# {
#     'index': [50, 51, 52, 53, 54],
#     '보험 발생(질병)': ['암, 기타피부암 또는 갑상선암', '암, 기타피부암 또는 갑상선암', '암, 기타피부암 또는 갑상선암', '암, 기타피부암 또는 갑상선암', '암, 기타피부암 또는 갑상선암'],
#     '보장 횟수': ['연간 1회한', '연간 1회한', '연간 1회한', '연간 1회한', '연간 1회한']
# }
# ```
#
# ```
# {
#     'index': [55, 56, 57, 58, 59],
#     '보험 발생(질병)': ['암, 기타피부암, 갑상선암', '3도 화상 또는 부식', '1종 수술', '2종 수술'],
#     '보장 횟수': ['연간 1회한', '최초 1회한', '최초 1회한', '수술시술코드당 연간1회한', '수술시술코드당 연간1회한']
# }
# ```
#
# ```
# {
# 'index': [60, 61, 62, 63, 64],
# '보험 발생(질병)': ['3종 수술 및 시술', '4종 수술 및 시술', '5종 수술 및 시술', '6종 수술 및 시술', '7종 수술 및 시술'],
# '보장 횟수': ['수술시술코드당 연간1회한', '수술시술코드당 연간1회한', '수술시술코드당 연간1회한', '수술시술코드당 연간1회한', '수술시술코드당 연간1회한']
# }
# ```
# '''
# {'index': [65, 66, 67, 68, 69], '보험 발생(질병)': ['8종 수술 및 시술', '간호·간병통합서비스', '급성심근경색증', '뇌경색증', '화상'], '보장 횟수': ['수술시술코드당 연간1회한', '1일당', '최초 1회한', '최초 1회한', '치료시']}
# '''
# '''
# {'index': [70], '보험 발생(질병)': ['화상'], '보장 횟수': ['치료시']}
# '''

# %%
gpt_answers = []


for response in gpt_responses:
    try:
        response = response.replace('`', '')
        response = response.replace('\n', '')
        response = response.replace('=', '')
        response = response.replace('python', '')
        response = response.replace("'''", '')
        response = "'''" + response + "'''"


        response = ast.literal_eval(response)
        response = ast.literal_eval(response)
        
        gpt_answers.append(response)
    except (SyntaxError, ValueError) as e:
        print(traceback.print_exc())
        break

# %%
result_df=pd.DataFrame(columns=['index', '보험 발생(질병)', '보장 횟수'])

for answers in gpt_answers:
    try:
        temp_df = pd.DataFrame(answers)
        result_df = pd.concat([result_df, temp_df], join='inner')
    except ValueError as e:
        print(traceback.print_exc())
        print(answers)
        break

# %%
pd.set_option('display.max_rows', 400)

# %%
result_df = result_df.drop('index', axis=1).reset_index(drop=True)

# %%
data = data.join(result_df)

# %%
pd.
# Out:
#       유형1   유형2                                    보험 보장 대상  \
# 0      입원  간병인1          (체증형)상해 입원 간병인 사용일당(1일이상)(요양병원 제외)
# 1      입원  간병인1             (체증형)상해 입원 간병인 사용일당(1일이상)(요양병원)
# 2      입원  간병인1          (체증형)질병 입원 간병인 사용일당(1일이상)(요양병원 제외)
# 3      입원  간병인1             (체증형)질병 입원 간병인 사용일당(1일이상)(요양병원)
# 4      입원  간병인2  (체증형,20년후2배)상해 입원 간병인 사용일당(1 일이상)(요양병원 제외)
# 5      입원  간병인2     (체증형,20년후2배)상해 입원 간병인 사용일당(1 일이상)(요양병원)
# 6      입원  간병인2  (체증형,20년후2배)질병 입원 간병인 사용일당(1 일이상)(요양병원 제외)
# 7      입원  간병인2     (체증형,20년후2배)질병 입원 간병인 사용일당(1 일이상)(요양병원)
# 8      생활  일상배상                        [갱신형] 가족 일상생활중 배상책임Ⅱ
# 9      수술  로봇수술                   [갱신형] 암(특정암 제외) 다빈치로봇 수술비
# 10     수술  로봇수술                         [갱신형] 특정암 다빈치로봇 수술비
# 11     생활  일상배상                    [공제][갱신형] 가족 일상생활중 배상책임Ⅱ
# 12     수술    질병                         111대질병 수술비(19대생활질병)
# 13     수술    질병                         111대질병 수술비(22대주요질병)
# 14     수술    질병                          111대질병 수술비(3대주요질병)
# 15     수술    질병                        111대질병 수술비(5대주요기관관혈)
# 16     수술    질병                       111대질병 수술비(5대주요기관비관혈)
# 17     수술    질병                         111대질병 수술비(62대생활질병)
# 18     수술    질병                       4대특정질병 치료·수술비(3대특정질병)
# 19     수술    질병                         4대특정질병 치료·수술비(선천이상)
# 20     수술    골절                                    5대골절 수술비
# 21     진단   갑상선                                갑상선기능저하증 진단비
# 22     진단   갑상선                                갑상선기능항진증 치료비
# 23     진단    골절                                      골절 진단비
# 24     진단    골절                    골절 진단비(치아파절(깨짐, 부러짐) 제외)
# 25     진단     암       기타피부암 및 갑상선암 진단후 암특정치료비(진단후5년, 연간1회한)
# 26     진단     암                         기타피부암 및 갑상선암 치료비 지원
# 27     진단    골절                             깁스 치료비(부목치료 제외)
# 28     진단    상해                                 보험료 납입면제대상Ⅱ
# 29     수술    상해                             상해 1종 수술비(시술포함)
# 30     수술    상해                             상해 2종 수술비(시술포함)
# 31     수술    상해                             상해 3종 수술비(시술포함)
# 32     수술    상해                             상해 4종 수술비(시술포함)
# 33     수술    상해                             상해 5종 수술비(시술포함)
# 34     수술    상해                             상해 6종 수술비(시술포함)
# 35     수술    상해                             상해 7종 수술비(시술포함)
# 36     수술    상해                             상해 8종 수술비(시술포함)
# 37     수술    상해                                   상해 골절 수술비
# 38  간병/사망    상해                                       상해 사망
# 39     입원    상해                 상해 입원 간호·간병통합서비스 사용일당(1일이상)
# 40  장해/장애    상해                             상해 후유장해(3~100%)
# 41     수술    상해                                아킬레스힘줄손상 수술비
# 42     진단     암                   암(기타피부암 및 갑상선암 제외) 치료비 지원
# 43     진단     암     암(기타피부암및갑상선암제외) 진단후 암특정치료비(진단후5년,연간1회한)
# 44     진단     암                                  유사암진단 납입지원
# 45     진단  응급의료                      응급의료 아나필락시스 진단비(연간1회한)
# 46     수술  인공관절                                  인공관절치환 수술비
# 47     진단     암          종합병원 암 특정치료지원금(연간 1억원 이상, 진단 후 5년)
# 48     진단     암         종합병원 암 특정치료지원금(연간 1천만원 이상, 진단 후 5년)
# 49     진단     암         종합병원 암 특정치료지원금(연간 2천만원 이상, 진단 후 5년)
# 50     진단     암         종합병원 암 특정치료지원금(연간 3천만원 이상, 진단 후 5년)
# 51     진단     암         종합병원 암 특정치료지원금(연간 4천만원 이상, 진단 후 5년)
# 52     진단     암         종합병원 암 특정치료지원금(연간 5천만원 이상, 진단 후 5년)
# 53     진단     암         종합병원 암 특정치료지원금(연간 6천만원 이상, 진단 후 5년)
# 54     진단     암         종합병원 암 특정치료지원금(연간 7천만원 이상, 진단 후 5년)
# 55     진단     암         종합병원 암 특정치료지원금(연간 8천만원 이상, 진단 후 5년)
# 56     진단     암         종합병원 암 특정치료지원금(연간 9천만원 이상, 진단 후 5년)
# 57     진단    화상                                중대 화상·부식 진단비
# 58     수술    질병                             질병 1종 수술비(시술포함)
# 59     수술    질병                             질병 2종 수술비(시술포함)
# 60     수술    질병                             질병 3종 수술비(시술포함)
# 61     수술    질병                             질병 4종 수술비(시술포함)
# 62     수술    질병                             질병 5종 수술비(시술포함)
# 63     수술    질병                             질병 6종 수술비(시술포함)
# 64     수술    질병                             질병 7종 수술비(시술포함)
# 65     수술    질병                             질병 8종 수술비(시술포함)
# 66     입원  간호간병                 질병 입원 간호·간병통합서비스 사용일당(1일이상)
# 67     수술  심근경색                            혈전용해치료비(급성심근경색증)
# 68     수술  심근경색                               혈전용해치료비(뇌경색증)
# 69     수술    화상                                      화상 수술비
# 70     진단    화상                                      화상 진단비
#
#                                                 상세 설명   보장단위       보장금액  \
# 0   상해사고로 병·의원(요양병원 제외) 등에 1일이상 계속 입원하여 치료를 받 으며, ...     1일     150000
# 1   상해사고로 요양병원에 1일이상 계속 입원하여 치료를 받으며, 약관에 정한 간병인을 ...     1일      30000
# 2   보험기간 중 질병으로 병·의원(요양병원 제외) 등에 1일이상 계속 입원하여 치료를 ...     1일     150000
# 3   보험기간 중 질병으로 요양병원에 1일이상 계속 입원하여 치료를 받으며, 약관에 정한...     1일      10000
# 4   상해사고로 병·의원(요양병원 제외) 등에 1일이상 계속 입원하여 치료를 받 으며, ...     1일     150000
# 5   상해사고로 요양병원에 1일이상 계속 입원하여 치료를 받으며, 약관에 정한 간병인을 ...     1일      30000
# 6   보험기간 중 질병으로 병·의원(요양병원 제외) 등에 1일이상 계속 입원하여 치료를 ...     1일     150000
# 7   보험기간 중 질병으로 요양병원에 1일이상 계속 입원하여 치료를 받으며, 약관에 정한...     1일      30000
# 8   본인 및 약관에 정한 가족의 일상생활 및 보험증권에 기재된 주택의 소유, 사용 또는...    발생시  100000000
# 9   보장개시일 이후 암(특정암 제외)으로 진단 확정되고 그 암(특정암 제외)의 직접적인...  최초 1회   20000000
# 10  보장개시일 이후 특정암(갑상선암, 전립선암)으로 진단 확정되고 그 특정암 의 직접적...  최초 1회   10000000
# 11    ※ 1사고당 자기부담금 : 대인 없음, 대물누수사고 50만원, 대물누수사고외 20만원    발생시     500000
# 12  보험기간 중 약관에 정한 19대 생활질병으로 진단 확정되고 그 치료를 직접 적인 목...    발생시     100000
# 13  보험기간 중 약관에 정한 22대 주요질병으로 진단 확정되고 그 치료를 직접 적인 목...    발생시    1000000
# 14  보험기간 중 약관에 정한 갑상선질환, 고혈압 및 당뇨병으로 진단 확정되고 그 치료를...    발생시     500000
# 15  보험기간 중 약관에 정한 뇌질환, 심질환, 간·췌장질환 및 폐질환으로 진단 확정되고...    발생시   20000000
# 16  보험기간 중 약관에 정한 뇌질환, 심질환, 간·췌장질환 및 폐질환으로 진단 확정되고...    발생시   10000000
# 17  보험기간 중 약관에 정한 62대 생활질병으로 진단 확정되고 그 치료를 직접 적인 목...    발생시     200000
# 18  보험기간 중 약관에 정한 체외충격파쇄석술(급여) 치료, 제왕절개만출술(급 여) 수술...  연간 1회     200000
# 19  보험기간 중 약관에 정한 선천성이상 질병의 치료를 직접적인 목적으로 수 술을 받은 ...  연간 1회     200000
# 20                 상해사고로 약관에 정한 5대골절로 수술받은 경우 가입금액 지급    발생시     500000
# 21  보험기간 중 약관에서 정한 「갑상선기능저하증」으로 진단 확정된 경우 가입 금액 지급...  최초 1회    1000000
# 22  보험기간 중 약관에서 정한 「갑상선기능항진증」으로 진단 확정되고 「갑상선 기능항진증...  최초 1회    2000000
# 23                 상해사고로 약관에 정한 골절로 진단 확정된 경우 가입금액 지급    발생시     100000
# 24  상해사고로 약관에 정한 골절(치아파절(깨짐, 부러짐) 제외)로 진단 확정된 경우 가...    발생시     200000
# 25  보장개시일 이후 기타피부암 또는 갑상선암으로 진단 확정되고 「기타피부암 및 갑상선암...  연간 1회    1000000
# 26  보장개시일 이후 기타피부암 또는 갑상선암으로 진단 확정된 경우 가입금액 지급(최초 ...  최초 1회     100000
# 27  보험기간 중 상해 또는 질병으로 약관에 정한 깁스치료를 받은 경우 가입금 액 지급\...    발생시     100000
# 28  보장개시일 이후 상해사고로 80%이상 후유장해가 발생하거나 약관에서 정 한 암, 뇌...  최초 1회     100000
# 29  보험기간 중 상해의 치료를 직접적인 목적으로 약관에서 정한 1종 수술 및 시술을 받...  연간 1회     300000
# 30  보험기간 중 상해의 치료를 직접적인 목적으로 약관에서 정한 2종 수술 및 시술을 받...  연간 1회     300000
# 31  보험기간 중 상해의 치료를 직접적인 목적으로 약관에서 정한 3종 수술 및 시술을 받...  연간 1회     450000
# 32  보험기간 중 상해의 치료를 직접적인 목적으로 약관에서 정한 4종 수술 및 시술을 받...  연간 1회     450000
# 33  보험기간 중 상해의 치료를 직접적인 목적으로 약관에서 정한 5종 수술 및 시술을 받...  연간 1회    5000000
# 34  보험기간 중 상해의 치료를 직접적인 목적으로 약관에서 정한 6종 수술 및 시술을 받...  연간 1회   10000000
# 35  보험기간 중 상해의 치료를 직접적인 목적으로 약관에서 정한 7종 수술 및 시술을 받...  연간 1회   15000000
# 36  보험기간 중 상해의 치료를 직접적인 목적으로 약관에서 정한 8종 수술 및 시술을 받...  연간 1회   25000000
# 37                   상해사고로 약관에 정한 골절로 수술받은 경우 가입금액 지급    발생시     200000
# 38                               상해사고로 사망한 경우 가입금액 지급    발생시   50000000
# 39  상해사고로 병원(요양병원 제외)에 1일이상 계속 입원하여 치료를 받으며, 약관에 정...     1일      70000
# 40                     상해사고로 후유장해가 발생한 경우 가입금액 한도로 지급    발생시   20000000
# 41   상해사고로 약관에 정한 아킬레스힘줄손상으로 진단확정되어 수술을 받은 경우 가입금액 지급    발생시    1000000
# 42  보장개시일 이후 암으로 진단 확정된 경우 가입금액 지급(최초 1회한)\n※ 암의 보...  최초 1회     100000
# 43  보장개시일 이후 암으로 진단 확정되고 「암(기타피부암 및 갑상선암 제외) 보험금 지...  연간 1회   10000000
# 44  이 특별약관의 보험기간 중 「기타피부암」,「갑상선암」,「대장점막내암」,「제자 리암」...    발생시      66000
# 45  보험기간 중 응급실에 내원하여 약관에서 정한 아나필락시스(anaphylaxis) 로...  연간 1회    2000000
# 46  보험기간 중 상해 또는 질병으로 약관에 정한 인공관절치환 수술을 받은 경우 가입금액...  최초 1회    2500000
# 47  보장개시일 이후 암, 기타피부암 또는 갑상선암으로 진단 확정되고 「암 보험 금 지급...  연간 1회   10000000
# 48  보장개시일 이후 암, 기타피부암 또는 갑상선암으로 진단 확정되고 「암 보험 금 지급...  연간 1회   10000000
# 49  보장개시일 이후 암, 기타피부암 또는 갑상선암으로 진단 확정되고 「암 보험 금 지급...  연간 1회   10000000
# 50  보장개시일 이후 암, 기타피부암 또는 갑상선암으로 진단 확정되고 「암 보험 금 지급...  연간 1회   10000000
# 51  보장개시일 이후 암, 기타피부암 또는 갑상선암으로 진단 확정되고 「암 보험 금 지급...  연간 1회   10000000
# 52  보장개시일 이후 암, 기타피부암 또는 갑상선암으로 진단 확정되고 「암 보험 금 지급...  연간 1회   10000000
# 53  보장개시일 이후 암, 기타피부암 또는 갑상선암으로 진단 확정되고 「암 보험 금 지급...  연간 1회   10000000
# 54  보장개시일 이후 암, 기타피부암 또는 갑상선암으로 진단 확정되고 「암 보험 금 지급...  연간 1회   10000000
# 55  보장개시일 이후 암, 기타피부암 또는 갑상선암으로 진단 확정되고 「암 보험 금 지급...  연간 1회   10000000
# 56  보장개시일 이후 암, 기타피부암 또는 갑상선암으로 진단 확정되고 「암 보험 금 지급...  연간 1회   10000000
# 57  상해사고로 신체 표면적으로 최소 20%이상의 3도 화상 또는 부식(화학약 품 등에 ...  최초 1회   10000000
# 58  보험기간 중 질병의 치료를 직접적인 목적으로 약관에서 정한 1종 수술 및 시술을 받...  연간 1회     300000
# 59  보험기간 중 질병의 치료를 직접적인 목적으로 약관에서 정한 2종 수술 및 시술을 받...  연간 1회     300000
# 60  보험기간 중 질병의 치료를 직접적인 목적으로 약관에서 정한 3종 수술 및 시술을 받...  연간 1회     450000
# 61  보험기간 중 질병의 치료를 직접적인 목적으로 약관에서 정한 4종 수술 및 시술을 받...  연간 1회     450000
# 62  보험기간 중 질병의 치료를 직접적인 목적으로 약관에서 정한 5종 수술 및 시술을 받...  연간 1회    3000000
# 63  보험기간 중 질병의 치료를 직접적인 목적으로 약관에서 정한 6종 수술 및 시술을 받...  연간 1회    6000000
# 64  보험기간 중 질병의 치료를 직접적인 목적으로 약관에서 정한 7종 수술 및 시술을 받...  연간 1회    9000000
# 65  보험기간 중 질병의 치료를 직접적인 목적으로 약관에서 정한 8종 수술 및 시술을 받...  연간 1회   15000000
# 66  보험기간 중 질병으로 병원(요양병원 제외)에 1일이상 계속 입원하여 치료 를 받으며...     1일      70000
# 67  보험기간 중 약관에서 정한 급성심근경색증으로 진단 확정되고, 그 치료를 직접적인 목...  최초 1회   10000000
# 68  보험기간 중 약관에서 정한 뇌경색증으로 진단 확정되고, 그 치료를 직접적 인 목적으...  최초 1회   10000000
# 69  상해사고로 심재성 2도 이상에 해당하는 화상으로 진단 확정 후 그 치료를 직접적인 ...    발생시     300000
# 70      상해사고로 심재성 2도 이상에 해당하는 화상으로 진단 확정된 경우 가입금 액 지급    발생시     100000
#
#     월 보험료  기본 보험료  할증 보험료   그룹    보험기간  납입기간(년)  갱신   만기 보험료  보장 대비 납입율  \
# 0    7305    7305     NaN  NaN  100세만기       20   납  1753200  11.688000
# 1     393     393     NaN  NaN  100세만기       20   납    94320   3.144000
# 2   25297   17265  8032.0  NaN  100세만기       20   납  6071280  40.475200
# 3    3438    2374  1064.0  NaN  100세만기       20   납   825120  82.512000
# 4    7695    7695     NaN  NaN  100세만기       20   납  1846800  12.312000
# 5     396     396     NaN  NaN  100세만기       20   납    95040   3.168000
# 6   26733   18240  8493.0  NaN  100세만기       20   납  6415920  42.772800
# 7   10338    7131  3207.0  NaN  100세만기       20   납  2481120  82.704000
# 8    1154    1154     NaN  NaN  100세만기       20  갱신   276960   0.002770
# 9    1120    1120     NaN  NaN  100세만기       10  갱신   134400   0.006720
# 10    200     200     NaN  NaN  100세만기       10  갱신    24000   0.002400
# 11      0       0     NaN  NaN  100세만기       20  갱신        0   0.000000
# 12     22      15     7.0  NaN  100세만기       20   납     5280   0.052800
# 13    704     482   222.0  NaN  100세만기       20   납   168960   0.168960
# 14    275     188    87.0  NaN  100세만기       20   납    66000   0.132000
# 15   7320    7320     NaN  NaN  100세만기       20   납  1756800   0.087840
# 16   2110    2110     NaN  NaN  100세만기       20   납   506400   0.050640
# 17   3419    2322  1097.0  NaN  100세만기       20   납   820560   4.102800
# 18    124     124     NaN    f  100세만기       20   납    29760   0.148800
# 19    124     124     NaN    f  100세만기       20   납    29760   0.148800
# 20     80      80     NaN  NaN  100세만기       20   납    19200   0.038400
# 21    170     170     NaN  NaN  100세만기       20   납    40800   0.040800
# 22    260     260     NaN  NaN  100세만기       20   납    62400   0.031200
# 23    898     898     NaN  NaN  100세만기       20   납   215520   2.155200
# 24   1140    1140     NaN  NaN  100세만기       20   납   273600   1.368000
# 25    130     130     NaN  NaN  100세만기       20   납    31200   0.031200
# 26     12      12     NaN  NaN  100세만기       20   납     2880   0.028800
# 27    123     123     NaN  NaN  100세만기       20   납    29520   0.295200
# 28    168     168     NaN  NaN  100세만기       20   납    40320   0.403200
# 29    546     546     NaN    b  100세만기       20   납   131040   0.436800
# 30    546     546     NaN    b  100세만기       20   납   131040   0.436800
# 31    546     546     NaN    b  100세만기       20   납   131040   0.291200
# 32    546     546     NaN    b  100세만기       20   납   131040   0.291200
# 33    267     267     NaN    c  100세만기       20   납    64080   0.012816
# 34    266     266     NaN    c  100세만기       20   납    63840   0.006384
# 35    266     266     NaN    c  100세만기       20   납    63840   0.004256
# 36    266     266     NaN    c  100세만기       20   납    63840   0.002554
# 37    372     372     NaN  NaN  100세만기       20   납    89280   0.446400
# 38   2550    2550     NaN  NaN  100세만기       20   납   612000   0.012240
# 39    805     805     NaN  NaN  100세만기       20   납   193200   2.760000
# 40   1000    1000     NaN  NaN  100세만기       20   납   240000   0.012000
# 41     60      60     NaN  NaN  100세만기       20   납    14400   0.014400
# 42    115     115     NaN  NaN  100세만기       20   납    27600   0.276000
# 43  14630   14630     NaN  NaN  100세만기       20   납  3511200   0.351120
# 44    488     488     NaN  NaN   20년만기       20   납   117120   1.774545
# 45    200     200     NaN  NaN  100세만기       20   납    48000   0.024000
# 46    775     775     NaN  NaN  100세만기       20   납   186000   0.074400
# 47    387     387     NaN  NaN  100세만기       20   납    92880   0.009288
# 48   5449    5449     NaN  NaN  100세만기       20   납  1307760   0.130776
# 49   2390    2390     NaN  NaN  100세만기       20   납   573600   0.057360
# 50   1581    1581     NaN  NaN  100세만기       20   납   379440   0.037944
# 51   1164    1164     NaN  NaN  100세만기       20   납   279360   0.027936
# 52    808     808     NaN  NaN  100세만기       20   납   193920   0.019392
# 53    638     638     NaN  NaN  100세만기       20   납   153120   0.015312
# 54    539     539     NaN  NaN  100세만기       20   납   129360   0.012936
# 55    473     473     NaN  NaN  100세만기       20   납   113520   0.011352
# 56    421     421     NaN  NaN  100세만기       20   납   101040   0.010104
# 57     51      51     NaN  NaN  100세만기       20   납    12240   0.001224
# 58   3648    2454  1194.0    d  100세만기       20   납   875520   2.918400
# 59   3646    2453  1193.0    d  100세만기       20   납   875040   2.916800
# 60   3646    2453  1193.0    d  100세만기       20   납   875040   1.944533
# 61   3646    2453  1193.0    d  100세만기       20   납   875040   1.944533
# 62   5058    3411  1647.0    e  100세만기       20   납  1213920   0.404640
# 63   5056    3410  1646.0    e  100세만기       20   납  1213440   0.202240
# 64   5056    3410  1646.0    e  100세만기       20   납  1213440   0.134827
# 65   5056    3410  1646.0    e  100세만기       20   납  1213440   0.080896
# 66   3425    2331  1094.0  NaN  100세만기       20   납   822000  11.742857
# 67    445     445     NaN    a  100세만기       20   납   106800   0.010680
# 68    445     445     NaN    a  100세만기       20   납   106800   0.010680
# 69     11      11     NaN  NaN  100세만기       20   납     2640   0.008800
# 70     76      76     NaN  NaN  100세만기       20   납    18240   0.182400
#
#                                보험 발생(질병)                   보장 횟수
# 0                                    간병인                     1일당
# 1                                    간병인                     1일당
# 2                                    간병인                     1일당
# 3                                    간병인                     1일당
# 4                                    간병인                     1일당
# 5                                    간병인            가입후 20년 미만 시
# 6                                    간병인                     1일당
# 7                                    간병인            가입후 20년 미만 시
# 8                             대인, 대물의 손해                    1사고당
# 9                              암(특정암 제외)                  최초 1회한
# 10                            갑상선암, 전립선암                   최초 1회
# 11                                    사고                    1사고당
# 12                              19대 생활질병                  수술당 1회
# 13                              22대 주요질병                  수술당 1회
# 14                      갑상선질환, 고혈압 및 당뇨병                  수술당 1회
# 15                뇌질환, 심질환, 간·췌장질환 및 폐질환                  수술당 1회
# 16                뇌질환, 심질환, 간·췌장질환 및 폐질환                  수술당 1회
# 17                              62대 생활질병                  수술당 1회
# 18                                   요실금                  연간 1회한
# 19                              선천성이상 질병                  연간 1회한
# 20                               5대골절 수술                 수술받은 경우
# 21                              갑상선기능저하증                   최초 1회
# 22                              갑상선기능항진증                   최초 1회
# 23                                    골절               진단 확정된 경우
# 24                              골절(치아파절)               진단 확정된 경우
# 25                           기타피부암, 갑상선암                  연간 1회한
# 26                           기타피부암, 갑상선암                  최초 1회한
# 27                                  깁스치료                     치료시
# 28  암, 뇌졸중, 급성심근경색증, 중대 화상·부식, 뇌·내장손상 수술                  최초 1회한
# 29                                    상해           수술시술코드당 연간1회한
# 30                            2종 수술 및 시술           수술시술코드당 연간1회한
# 31                            3종 수술 및 시술           수술시술코드당 연간1회한
# 32                            4종 수술 및 시술           수술시술코드당 연간1회한
# 33                            5종 수술 및 시술           수술시술코드당 연간1회한
# 34                            6종 수술 및 시술           수술시술코드당 연간1회한
# 35                                상해의 치료           수술시술코드당 연간1회한
# 36                                상해의 치료           수술시술코드당 연간1회한
# 37                                    골절                 수술받은 경우
# 38                                    사망                      1회
# 39                            간호·간병통합서비스                     1일당
# 40                                  후유장해                     한도로
# 41                              아킬레스힘줄손상                 수술받은 경우
# 42                                     암                   최초 1회
# 43                    암(기타피부암 및 갑상선암 제외)                  연간 1회한
# 44      기타피부암, 갑상선암, 대장점막내암, 제자리암, 경계성종양  차회 이후 이 계약의 보험료 납 입시마다
# 45                                아나필락시스                  연간 1회한
# 46                                인공관절치환               최초 1회한 지급
# 47                      암, 기타피부암 또는 갑상선암                  연간 1회한
# 48                      암, 기타피부암 또는 갑상선암                  연간 1회한
# 49                      암, 기타피부암 또는 갑상선암                  연간 1회한
# 50                      암, 기타피부암 또는 갑상선암                  연간 1회한
# 51                      암, 기타피부암 또는 갑상선암                  연간 1회한
# 52                      암, 기타피부암 또는 갑상선암                  연간 1회한
# 53                      암, 기타피부암 또는 갑상선암                  연간 1회한
# 54                      암, 기타피부암 또는 갑상선암                  연간 1회한
# 55                        암, 기타피부암, 갑상선암                  연간 1회한
# 56                        암, 기타피부암, 갑상선암                  최초 1회한
# 57                           3도 화상 또는 부식                  최초 1회한
# 58                                 1종 수술           수술시술코드당 연간1회한
# 59                                 2종 수술           수술시술코드당 연간1회한
# 60                            3종 수술 및 시술           수술시술코드당 연간1회한
# 61                            4종 수술 및 시술           수술시술코드당 연간1회한
# 62                            5종 수술 및 시술           수술시술코드당 연간1회한
# 63                            6종 수술 및 시술           수술시술코드당 연간1회한
# 64                            7종 수술 및 시술           수술시술코드당 연간1회한
# 65                            8종 수술 및 시술           수술시술코드당 연간1회한
# 66                            간호·간병통합서비스                     1일당
# 67                               급성심근경색증                  최초 1회한
# 68                                  뇌경색증                  최초 1회한
# 69                                    화상                     치료시
# 70                                    화상                     치료시

# %%
data.to_excel('preprocessed_data_txt-sum.xlsx', index=False)
