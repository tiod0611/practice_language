# %%
import pandas as pd
from ydata_profiling import ProfileReport

import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', 40)

# %%
def data_summary(df):
    """
    주어진 DataFrame에서 각 열의 요약 통계를 계산하고 결과를 새로운 DataFrame으로 반환한다.

    Parameters:
        df (DataFrame): 분석할 데이터를 포함한 pandas DataFrame.

    Returns:
        DataFrame: 각 열의 데이터 타입, 개수, 고유값 개수, 결측치 개수, 결측치 비율, 고유값을 포함한 요약 정보.
    """
    obs = df.shape[0]
    types = df.dtypes
    counts = df.apply(lambda x: x.count())
    uniques = df.apply(lambda x: [x.unique()]).T.squeeze()
    nulls = df.apply(lambda x: x.isnull().sum())
    distincts = df.apply(lambda x: x.unique().shape[0])
    missing_ratio = (df.isnull().sum() / obs)*100
    
    print("Data shape: ", df.shape)

    cols = ['Types', 'Counts', 'Distincts', 'Nulls', 'Missing_ratio', 'Uniques']
    structure = pd.concat([types, counts, distincts, nulls, missing_ratio, uniques], axis=1, sort=True)

    structure.columns = cols

    print("================================================")
    print("Data types: ")
    print(structure['Types'].value_counts())
    print("================================================")
    print("\n\n")

    return structure

# %%
data = pd.read_excel('보험데이터_체증형_통합.xlsx')

# %%
data_summary(data)
# Out:
# Data shape:  (71, 11)
# ================================================
# Data types:
# Types
# object     7
# int64      3
# float64    1
# Name: count, dtype: int64
# ================================================
#              Types  Counts  Distincts  Nulls  Missing_ratio  \
# 그룹          object      20          7     51      71.830986
# 기본 보험료       int64      71         59      0       0.000000
# 납입기간/보험기간   object      71          5      0       0.000000
# 보장금액         int64      71         23      0       0.000000
# 보장단위        object      71          4      0       0.000000
# 보험 보장 대상    object      71         71      0       0.000000
# 상세 설명       object      71         71      0       0.000000
# 유형1         object      71          6      0       0.000000
# 유형2         object      71         14      0       0.000000
# 총 보험료        int64      71         59      0       0.000000
# 할증 보험료     float64      17         14     54      76.056338
#
#                                            Uniques
# 그룹                         [nan, f, b, c, d, e, a]
# 기본 보험료     [7305, 393, 17265, 2374, 7695, 396, ...
# 납입기간/보험기간  [20년납 100세만기, 20년납\n100세만기, 20년갱신 10...
# 보장금액       [150000, 30000, 10000, 100000000, 20...
# 보장단위                       [1일, 발생시, 최초 1회, 연간 1회]
# 보험 보장 대상   [(체증형)상해 입원 간병인 사용일당(1일이상)(요양병원 제외),...
# 상세 설명      [상해사고로 병·의원(요양병원 제외) 등에 1일이상 계속 입원하여...
# 유형1                 [입원, 생활, 수술, 진단, 간병/사망, 장해/장애]
# 유형2        [간병인1, 간병인2, 일상배상, 로봇수술, 질병, 골절, 갑상선...
# 총 보험료      [7305, 393, 25297, 3438, 7695, 396, ...
# 할증 보험료     [nan, 8032.0, 1064.0, 8493.0, 3207.0...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   유형1        71 non-null     object
#  1   유형2        71 non-null     object
#  2   보험 보장 대상   71 non-null     object
#  3   상세 설명      71 non-null     object
#  4   보장단위       71 non-null     object
#  5   보장금액       71 non-null     int64
#  6   총 보험료      71 non-null     int64
#  7   기본 보험료     71 non-null     int64
#  8   할증 보험료     17 non-null     float64
#  9   납입기간/보험기간  71 non-null     object
#  10  그룹         20 non-null     object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 6.2+ KB

# %%
data.sample(10)
# Out:
#    유형1   유형2                             보험 보장 대상  \
# 45  진단  응급의료               응급의료 아나필락시스 진단비(연간1회한)
# 19  수술    질병                  4대특정질병 치료·수술비(선천이상)
# 21  진단   갑상선                         갑상선기능저하증 진단비
# 27  진단    골절                      깁스 치료비(부목치료 제외)
# 63  수술    질병                      질병 6종 수술비(시술포함)
# 55  진단     암  종합병원 암 특정치료지원금(연간 8천만원 이상, 진단 후 5년)
# 49  진단     암  종합병원 암 특정치료지원금(연간 2천만원 이상, 진단 후 5년)
# 26  진단     암                  기타피부암 및 갑상선암 치료비 지원
# 33  수술    상해                      상해 5종 수술비(시술포함)
# 28  진단    상해                          보험료 납입면제대상Ⅱ
#
#                                       상세 설명   보장단위      보장금액  총 보험료  기본 보험료  \
# 45  보험기간 중 응급실에 내원하여 약관에서 정한 아나필락시스(anap...  연간 1회   2000000    200     200
# 19  보험기간 중 약관에 정한 선천성이상 질병의 치료를 직접적인 목적으...  연간 1회    200000    124     124
# 21  보험기간 중 약관에서 정한 「갑상선기능저하증」으로 진단 확정된 경...  최초 1회   1000000    170     170
# 27  보험기간 중 상해 또는 질병으로 약관에 정한 깁스치료를 받은 경우...    발생시    100000    123     123
# 63  보험기간 중 질병의 치료를 직접적인 목적으로 약관에서 정한 6종 ...  연간 1회   6000000   5056    3410
# 55  보장개시일 이후 암, 기타피부암 또는 갑상선암으로 진단 확정되고 ...  연간 1회  10000000    473     473
# 49  보장개시일 이후 암, 기타피부암 또는 갑상선암으로 진단 확정되고 ...  연간 1회  10000000   2390    2390
# 26  보장개시일 이후 기타피부암 또는 갑상선암으로 진단 확정된 경우 가...  최초 1회    100000     12      12
# 33  보험기간 중 상해의 치료를 직접적인 목적으로 약관에서 정한 5종 ...  연간 1회   5000000    267     267
# 28  보장개시일 이후 상해사고로 80%이상 후유장해가 발생하거나 약관에...  최초 1회    100000    168     168
#
#     할증 보험료    납입기간/보험기간   그룹
# 45     NaN  20년납 100세만기  NaN
# 19     NaN  20년납 100세만기    f
# 21     NaN  20년납 100세만기  NaN
# 27     NaN  20년납 100세만기  NaN
# 63  1646.0  20년납 100세만기    e
# 55     NaN  20년납 100세만기  NaN
# 49     NaN  20년납 100세만기  NaN
# 26     NaN  20년납 100세만기  NaN
# 33     NaN  20년납 100세만기    c
# 28     NaN  20년납 100세만기  NaN

# %%
# help(ProfileReport)

# %%
# profile = ProfileReport(data, title="Profiling Report")
# profile

# %% [markdown]
# ## 데이터 전처리

# %%
def split_data(x):
    """납입기간과 보험기간을 분리"""
    if ' ' in x:
        period = x.split(' ')[0]
        guarantee = x.split(' ')[1]
    elif '\n' in x:
        period = x.split('\n')[0]
        guarantee = x.split('\n')[1]

    return [period, guarantee]

# %%
data[['납입기간', '보장기간']] = data['납입기간/보험기간'].apply(lambda x: pd.Series(split_data(x)))

# %%
data.drop('납입기간/보험기간', inplace=True, axis=1)
data.sample(10)
# Out:
#    유형1   유형2                                 보험 보장 대상  \
# 6   입원  간병인2  (체증형,20년후2배)질병 입원 간병인 사용일당(1 일이상)(요양...
# 68  수술  심근경색                            혈전용해치료비(뇌경색증)
# 8   생활  일상배상                     [갱신형] 가족 일상생활중 배상책임Ⅱ
# 48  진단     암      종합병원 암 특정치료지원금(연간 1천만원 이상, 진단 후 5년)
# 11  생활  일상배상                 [공제][갱신형] 가족 일상생활중 배상책임Ⅱ
# 10  수술  로봇수술                      [갱신형] 특정암 다빈치로봇 수술비
# 50  진단     암      종합병원 암 특정치료지원금(연간 3천만원 이상, 진단 후 5년)
# 25  진단     암    기타피부암 및 갑상선암 진단후 암특정치료비(진단후5년, 연간1회한)
# 34  수술    상해                          상해 6종 수술비(시술포함)
# 36  수술    상해                          상해 8종 수술비(시술포함)
#
#                                       상세 설명   보장단위       보장금액  총 보험료  기본 보험료  \
# 6   보험기간 중 질병으로 병·의원(요양병원 제외) 등에 1일이상 계속...     1일     150000  26733   18240
# 68  보험기간 중 약관에서 정한 뇌경색증으로 진단 확정되고, 그 치료를...  최초 1회   10000000    445     445
# 8   본인 및 약관에 정한 가족의 일상생활 및 보험증권에 기재된 주택의...    발생시  100000000   1154    1154
# 48  보장개시일 이후 암, 기타피부암 또는 갑상선암으로 진단 확정되고 ...  연간 1회   10000000   5449    5449
# 11  ※ 1사고당 자기부담금 : 대인 없음, 대물누수사고 50만원, 대...    발생시     500000      0       0
# 10  보장개시일 이후 특정암(갑상선암, 전립선암)으로 진단 확정되고 그...  최초 1회   10000000    200     200
# 50  보장개시일 이후 암, 기타피부암 또는 갑상선암으로 진단 확정되고 ...  연간 1회   10000000   1581    1581
# 25  보장개시일 이후 기타피부암 또는 갑상선암으로 진단 확정되고 「기타...  연간 1회    1000000    130     130
# 34  보험기간 중 상해의 치료를 직접적인 목적으로 약관에서 정한 6종 ...  연간 1회   10000000    266     266
# 36  보험기간 중 상해의 치료를 직접적인 목적으로 약관에서 정한 8종 ...  연간 1회   25000000    266     266
#
#     할증 보험료   그룹   납입기간    보장기간
# 6   8493.0  NaN   20년납  100세만기
# 68     NaN    a   20년납  100세만기
# 8      NaN  NaN  20년갱신  100세만기
# 48     NaN  NaN   20년납  100세만기
# 11     NaN  NaN  20년갱신  100세만기
# 10     NaN  NaN  10년갱신  100세만기
# 50     NaN  NaN   20년납  100세만기
# 25     NaN  NaN   20년납  100세만기
# 34     NaN    c   20년납  100세만기
# 36     NaN    c   20년납  100세만기

# %%
data[data['보장기간']=='20년만기']
# Out:
#    유형1 유형2    보험 보장 대상                                    상세 설명 보장단위   보장금액  \
# 44  진단   암  유사암진단 납입지원  이 특별약관의 보험기간 중 「기타피부암」,「갑상선암」,「대장점막내...  발생시  66000
#
#     총 보험료  기본 보험료  할증 보험료   그룹  납입기간   보장기간
# 44    488     488     NaN  NaN  20년납  20년만기

# %%
# ['보험기간', '갱신']으로 나누기
data[['납입기간(년)', '갱신여부']] = data['납입기간'].str.split('년', expand=True)
data.drop('납입기간', inplace=True, axis=1)
data.sample(10)
# Out:
#    유형1   유형2                               보험 보장 대상  \
# 66  입원  간호간병            질병 입원 간호·간병통합서비스 사용일당(1일이상)
# 28  진단    상해                            보험료 납입면제대상Ⅱ
# 25  진단     암  기타피부암 및 갑상선암 진단후 암특정치료비(진단후5년, 연간1회한)
# 23  진단    골절                                 골절 진단비
# 57  진단    화상                           중대 화상·부식 진단비
# 63  수술    질병                        질병 6종 수술비(시술포함)
# 39  입원    상해            상해 입원 간호·간병통합서비스 사용일당(1일이상)
# 32  수술    상해                        상해 4종 수술비(시술포함)
# 30  수술    상해                        상해 2종 수술비(시술포함)
# 13  수술    질병                    111대질병 수술비(22대주요질병)
#
#                                       상세 설명   보장단위      보장금액  총 보험료  기본 보험료  \
# 66  보험기간 중 질병으로 병원(요양병원 제외)에 1일이상 계속 입원하...     1일     70000   3425    2331
# 28  보장개시일 이후 상해사고로 80%이상 후유장해가 발생하거나 약관에...  최초 1회    100000    168     168
# 25  보장개시일 이후 기타피부암 또는 갑상선암으로 진단 확정되고 「기타...  연간 1회   1000000    130     130
# 23       상해사고로 약관에 정한 골절로 진단 확정된 경우 가입금액 지급    발생시    100000    898     898
# 57  상해사고로 신체 표면적으로 최소 20%이상의 3도 화상 또는 부식...  최초 1회  10000000     51      51
# 63  보험기간 중 질병의 치료를 직접적인 목적으로 약관에서 정한 6종 ...  연간 1회   6000000   5056    3410
# 39  상해사고로 병원(요양병원 제외)에 1일이상 계속 입원하여 치료를 ...     1일     70000    805     805
# 32  보험기간 중 상해의 치료를 직접적인 목적으로 약관에서 정한 4종 ...  연간 1회    450000    546     546
# 30  보험기간 중 상해의 치료를 직접적인 목적으로 약관에서 정한 2종 ...  연간 1회    300000    546     546
# 13  보험기간 중 약관에 정한 22대 주요질병으로 진단 확정되고 그 치...    발생시   1000000    704     482
#
#     할증 보험료   그룹    보장기간 납입기간(년) 갱신여부
# 66  1094.0  NaN  100세만기      20    납
# 28     NaN  NaN  100세만기      20    납
# 25     NaN  NaN  100세만기      20    납
# 23     NaN  NaN  100세만기      20    납
# 57     NaN  NaN  100세만기      20    납
# 63  1646.0    e  100세만기      20    납
# 39     NaN  NaN  100세만기      20    납
# 32     NaN    b  100세만기      20    납
# 30     NaN    b  100세만기      20    납
# 13   222.0  NaN  100세만기      20    납

# %%
data[data['갱신여부']!='납']
# Out:
#    유형1   유형2                   보험 보장 대상  \
# 8   생활  일상배상       [갱신형] 가족 일상생활중 배상책임Ⅱ
# 9   수술  로봇수술  [갱신형] 암(특정암 제외) 다빈치로봇 수술비
# 10  수술  로봇수술        [갱신형] 특정암 다빈치로봇 수술비
# 11  생활  일상배상   [공제][갱신형] 가족 일상생활중 배상책임Ⅱ
#
#                                       상세 설명   보장단위       보장금액  총 보험료  기본 보험료  \
# 8   본인 및 약관에 정한 가족의 일상생활 및 보험증권에 기재된 주택의...    발생시  100000000   1154    1154
# 9   보장개시일 이후 암(특정암 제외)으로 진단 확정되고 그 암(특정암...  최초 1회   20000000   1120    1120
# 10  보장개시일 이후 특정암(갑상선암, 전립선암)으로 진단 확정되고 그...  최초 1회   10000000    200     200
# 11  ※ 1사고당 자기부담금 : 대인 없음, 대물누수사고 50만원, 대...    발생시     500000      0       0
#
#     할증 보험료   그룹    보장기간 납입기간(년) 갱신여부
# 8      NaN  NaN  100세만기      20   갱신
# 9      NaN  NaN  100세만기      10   갱신
# 10     NaN  NaN  100세만기      10   갱신
# 11     NaN  NaN  100세만기      20   갱신

# %%
# 항목별 전체 납입액 구하기
data.rename(columns={'총 보험료':'월 보험료'}, inplace=True)

# %%
data['총 보험료'] = data['월 보험료'] * data['납입기간(년)'].astype('int') * 12
data.head(10)
# Out:
#   유형1   유형2                                 보험 보장 대상  \
# 0  입원  간병인1       (체증형)상해 입원 간병인 사용일당(1일이상)(요양병원 제외)
# 1  입원  간병인1          (체증형)상해 입원 간병인 사용일당(1일이상)(요양병원)
# 2  입원  간병인1       (체증형)질병 입원 간병인 사용일당(1일이상)(요양병원 제외)
# 3  입원  간병인1          (체증형)질병 입원 간병인 사용일당(1일이상)(요양병원)
# 4  입원  간병인2  (체증형,20년후2배)상해 입원 간병인 사용일당(1 일이상)(요양...
# 5  입원  간병인2  (체증형,20년후2배)상해 입원 간병인 사용일당(1 일이상)(요양병원)
# 6  입원  간병인2  (체증형,20년후2배)질병 입원 간병인 사용일당(1 일이상)(요양...
# 7  입원  간병인2  (체증형,20년후2배)질병 입원 간병인 사용일당(1 일이상)(요양병원)
# 8  생활  일상배상                     [갱신형] 가족 일상생활중 배상책임Ⅱ
# 9  수술  로봇수술                [갱신형] 암(특정암 제외) 다빈치로봇 수술비
#
#                                      상세 설명   보장단위       보장금액  월 보험료  기본 보험료  \
# 0  상해사고로 병·의원(요양병원 제외) 등에 1일이상 계속 입원하여 ...     1일     150000   7305    7305
# 1  상해사고로 요양병원에 1일이상 계속 입원하여 치료를 받으며, 약관...     1일      30000    393     393
# 2  보험기간 중 질병으로 병·의원(요양병원 제외) 등에 1일이상 계속...     1일     150000  25297   17265
# 3  보험기간 중 질병으로 요양병원에 1일이상 계속 입원하여 치료를 받...     1일      10000   3438    2374
# 4  상해사고로 병·의원(요양병원 제외) 등에 1일이상 계속 입원하여 ...     1일     150000   7695    7695
# 5  상해사고로 요양병원에 1일이상 계속 입원하여 치료를 받으며, 약관...     1일      30000    396     396
# 6  보험기간 중 질병으로 병·의원(요양병원 제외) 등에 1일이상 계속...     1일     150000  26733   18240
# 7  보험기간 중 질병으로 요양병원에 1일이상 계속 입원하여 치료를 받...     1일      30000  10338    7131
# 8  본인 및 약관에 정한 가족의 일상생활 및 보험증권에 기재된 주택의...    발생시  100000000   1154    1154
# 9  보장개시일 이후 암(특정암 제외)으로 진단 확정되고 그 암(특정암...  최초 1회   20000000   1120    1120
#
#    할증 보험료   그룹    보장기간 납입기간(년) 갱신여부    총 보험료
# 0     NaN  NaN  100세만기      20    납  1753200
# 1     NaN  NaN  100세만기      20    납    94320
# 2  8032.0  NaN  100세만기      20    납  6071280
# 3  1064.0  NaN  100세만기      20    납   825120
# 4     NaN  NaN  100세만기      20    납  1846800
# 5     NaN  NaN  100세만기      20    납    95040
# 6  8493.0  NaN  100세만기      20    납  6415920
# 7  3207.0  NaN  100세만기      20    납  2481120
# 8     NaN  NaN  100세만기      20   갱신   276960
# 9     NaN  NaN  100세만기      10   갱신   134400

# %%
# 보장 받는 것에 비해 얼마나 많이 낼까?
data['보장 대비 납입율'] = data['총 보험료'] / data['보장금액']

# %%
data.to_excel('preprocessed_data.xlsx')

# %% [markdown]
# ## Text Summarization

# %%
from importlib import reload

import pandas as pd

import ast
import re
import traceback

import ChatGPT_API

# %%
data = pd.read_excel('preprocessed_data.xlsx')
# data.head()

# %%
# 배치 프로세싱을 어떻게 진행할 것인가. 하나의 qeury에 여러 메시지를 담아야하고, 그 결과를 분리해서 받을 수 있어야 한다. 
# 그렇다면 문장 요약에서 내가 얻고 싶은 정보는 무엇일까? 
# 1. 어떤 병을 대상으로 한 보험인지. 사실 이거면 된다. 보장 내용은 내가 수작업으로 했으니까.

# %%
N_BATCH = 5

# %%
data_list = data['상세 설명'].to_list()

# 예시 데이터, '상세 설명' 키에 여러 상세 내용이 리스트로 저장되어 있다고 가정
temp = {
    '상세 설명': [f'{i}' for i in data_list],  # 1부터 71까지의 상세 내용 예시
}

# 문서 내용을 담을 빈 문자열 초기화
contents = []

doc_index = 0
# 10개씩 상세 설명을 문서 내용에 포맷팅하여 추가
for i in range(0, len(data_list), N_BATCH):
    
    content = ''

    chunk = temp['상세 설명'][i:i+N_BATCH]
    for detail in chunk:
        content += f"""
        index: {doc_index}
        <문서 내용>
        {detail}

        """
        doc_index += 1
    
    contents.append(content)

# %%
reload(ChatGPT_API)
request_openai = ChatGPT_API.request_openai

gpt_responses = []

for ducument_content in contents:
    result = request_openai(ducument_content)
    gpt_responses.append(result)

# %%
for i in gpt_responses:
    print(i)
# Out:
# ```
# {
#     'index': [0, 1, 2, 3, 4],
#     '보험 발생(질병)': ['복·의원(요양병원 제외) 1일 이상 입원', '요양병원 1일 이상 입원', '질병 1일 이상 입원', '질병 요양병원 1일 이상 입원', '복·의원(요양병원 제외) 1일 이상 입원'],
#     '보장 횟수': ['1일 일당', '1일 일당', '1일 일당', '1일 일당', '1일 일당'],
#     '내용 요약': [
#         '상해로 1일 이상 병·의원(요양병원 제외) 입원 시 간병인 사용에 따라 일당 지급, 7만원 미만 50%, 7만원 이상 100% 할증 지급, 최대 180일.',
#         '상해로 1일 이상 요양병원 입원시 간병인 사용에 따라 일당 지급, 20년마다 10%씩 정액 할증, 최대 180일.',
#         '질병으로 1일 이상 입원시 간병인 사용에 따라 일당 지급, 7만원 미만 50%, 7만원 이상 100% 할증 지급, 최대 180일.',
#         '질병으로 요양병원 1일 이상 입원시 간병인 사용에 따라 일당 지급, 20년마다 10%씩 정액 할증, 최대 180일.',
#         '상해로 1일 이상 병·의원(요양병원 제외) 입원 시 간병인 사용에 따라 일당 지급, 20년 미만 50%, 20년 이상 100%, 7만원 이상 200%, 최대 180일.'
#     ]
# }
# ```
# ```
# {
#     'index': [5, 6, 7, 8, 9],
#     '보험 발생(질병)': ['간병인(요양병원)', '간병인(요양병원)', '간병인(요양병원)', '사고', '암(특정암 제외)'],
#     '보장 횟수': ['가입후 20년 미만 100%, 가입후 20년 이상 200%', '가입후 20년 미만 50%, 가입후 20년 이상 100%', '가입후 20년 미만 100%, 가입후 20년 이상 200%', '1사고당', '최초 1회'],
#     '내용 요약': [
#         '상해로 1일 이상 요양병원 입원시 간병인 사용에 따라 일당 지급. 20년 미만 100%, 20년 이상 200% 할증 지급, 최대 180일.',
#         '질병으로 병·의원(요양병원 제외) 등에 1일이상 계속 입원시 간병인 사용에 따라 일당 지급. 7만원 미만 50%, 7만원 이상 100% 할증 지급, 최대 180일.',
#         '질병으로 요양병원에 1일이상 계속 입원시 간병인 사용에 따라 일당 지급. 20년 미만 100%, 20년 이상 200% 할증 지급, 최대 180일.',
#         '본인 및 가족의 일상생활 및 주택 관련 사고 발생 시 가입금액 한도로 보상',
#         '암(특정암 제외) 진단 후 다빈치 수술 시 가입금액 지급, 보장개시일 90일 후, 최초 180일 내 25% 감액, 1년 내 50% 감액. 특정암: 갑상선암, 전립선암'
#     ]
# }
# ```
# ```
# {
#     'index': [10, 11, 12, 13, 14],
#     '보험 발생(질병)': ['갑상선암, 전립선암', '사고', '생활질병', '주요질병', '갑상선질환, 고혈압 및 당뇨병'],
#     '보장 횟수': ['최초 1회', '1사고당', '수술당 1회', '수술당 1회', '수술당 1회'],
#     '내용 요약': [
#         '특정암 진단 후 다빈치 수술 시 가입금액 지급, 보장개시 90일 후, 초기 감액 있음.',
#         '1사고당 자기부담금: 대인 없음, 대물누수 50만원, 기타 대물 20만원',
#         '19대 생활질병 수술 시 가입금액 지급, 1년 미만 50% 감액.',
#         '22대 주요질병 수술 시 가입금액 지급, 1년 미만 50% 감액.',
#         '갑상선질환, 고혈압 및 당뇨병 수술 시 가입금액 지급, 1년 미만 50% 감액.'
#     ],
# }
# ```
# ```
# {
#     'index': [15, 16, 17, 18, 19],
#     '보험 발생(질병)': ['뇌질환, 심질환, 간·췌장질환 및 폐질환', '뇌질환, 심질환, 간·췌장질환 및 폐질환', '62대 생활질병', '체외충격파쇄석술(급여) 치료, 제왕절개만출술(급여)', '선천성이상 질병'],
#     '보장 횟수': ['수술당 1회', '수술당 1회', '수술당 1회', '각각 연간 1회한', '연간 1회한'],
#     '내용 요약': [
#         '뇌질환, 심질환, 간·췌장질환 및 폐질환 관혈수술 시 가입금액 지급, 1년 미만 50% 감액.',
#         '뇌질환, 심질환, 간·췌장질환 및 폐질환 비관혈수술 시 가입금액 지급, 1년 미만 50% 감액.',
#         '62대 생활질병 수술 시 가입금액 지급, 1년 미만 50% 감액.',
#         '체외충격파쇄석술(급여) 치료, 제왕절개만출술(급여) 수술 및 요실금 수술(급여) 시 가입금액 지급, 1년 미만 50% 감액.',
#         '선천성이상 질병 수술 시 가입금액 지급, 1년 미만 50% 감액.'
#     ]
# }
# ```
# ```
# {
#     'index': [20, 21, 22, 23, 24],
#     '보험 발생(질병)': ['5대골절 수술', '갑상선기능저하증', '갑상선기능항진증', '골절', '골절(치아파절 제외)'],
#     '보장 횟수': ['수술받은 경우', '최초 1회', '최초 1회', '', ''],
#     '내용 요약': [
#         '5대 골절 수술 시 가입금액 지급',
#         '갑상선기능저하증 진단 시 가입금액 지급, 1년 미만 50% 감액',
#         '갑상선기능항진증 진단 및 치료 시 가입금액 지급, 1년 미만 50% 감액',
#         '골절 진단 시 가입금액 지급',
#         '골절(치아파절 제외) 진단 시 가입금액 지급'
#     ]
# }
# ```
# ```
# {
#     'index': [25, 26, 27, 28, 29],
#     '보험 발생(질병)': ['기타피부암, 갑상선암', '기타피부암, 갑상선암', '상해 또는 질병', '상해, 암, 뇌졸중, 급성심근경색증, 중대 화상·부식, 뇌·내장 손상 수술', '상해'],
#     '보장 횟수': ['연간 1회한', '최초 1회한','1회당', '최초 1회한','수술시술코드당 연간1회한'],
#     '내용 요약' : [
#         '기타피부암 또는 갑상선암 진단 후 특정치료 시 가입금액 지급. 보장개시일로부터 5년까지의 보험금 지급대상 기간 내 연간 1회한',
#         '기타피부암 또는 갑상선암 진단 시 가입금액 지급, 최초 1회한',
#         '상해 또는 질병으로 깁스치료 받을 시 가입금액 지급. 부목치료 제외',
#         '상해로 80%이상 후유장해 등 진단 시 가입금액 지급, 암, 뇌졸중, 급성심근경색증 등 진단 또는 수술 시 가입금액 지급, 최초 1회한',
#         '상해의 1종 수술 및 시술 직접 목적으로 받을 시 가입금액 지급, 1회의 입원 또는 통원당 1회의 수술 및 시술에 한하여 보장'
#     ],
# }
# ```
# ```
# {
#     'index': [30, 31, 32, 33, 34],
#     '보험 발생(질병)': ['상해의 치료를 직접적인 목적으로 2종 수술 및 시술', '상해의 치료를 직접적인 목적으로 3종 수술 및 시술', '상해의 치료를 직접적인 목적으로 4종 수술 및 시술', '상해의 치료를 직접적인 목적으로 5종 수술 및 시술', '상해의 치료를 직접적인 목적으로 6종 수술 및 시술'],
#     '보장 횟수': ['수술시술코드당 연간1회한', '수술시술코드당 연간1회한', '수술시술코드당 연간1회한', '수술시술코드당 연간1회한', '수술시술코드당 연간1회한'],
#     '내용 요약': [
#         '약관에서 정한 2종 수술 및 시술을 받은 경우, 수술시술코드당 연간 1회한 가입금액 지급. 1회의 입원 또는 통원당 1회의 수술 및 시술에 한하여 보장',
#         '약관에서 정한 3종 수술 및 시술을 받은 경우, 수술시술코드당 연간 1회한 가입금액 지급. 1회의 입원 또는 통원당 1회의 수술 및 시술에 한하여 보장',
#         '약관에서 정한 4종 수술 및 시술을 받은 경우, 수술시술코드당 연간 1회한 가입금액 지급. 1회의 입원 또는 통원당 1회의 수술 및 시술에 한하여 보장',
#         '약관에서 정한 5종 수술 및 시술을 받은 경우, 수술시술코드당 연간 1회한 가입금액 지급. 1회의 입원 또는 통원당 1회의 수술 및 시술에 한하여 보장',
#         '약관에서 정한 6종 수술 및 시술을 받은 경우, 수술시술코드당 연간 1회한 가입금액 지급. 1회의 입원 또는 통원당 1회의 수술 및 시술에 한하여 보장'
#     ]
# }
# ```
# ```
# {
#     'index': [35, 36, 37, 38, 39],
#     '보험 발생(질병)': ['7종 수술 및 시술', '8종 수술 및 시술', '골절', '사망', '간호·간병통합서비스'],
#     '보장 횟수': ['수술시술코드당 연간1회', '수술시술코드당 연간1회', '수술받은 경우', '한번', '1일 일당'],
#     '내용 요약' : [
#         '7종 수술 및 시술 시 가입금액 지급 (1회의 입원 또는 1회의 통원에 한하여 보장)',
#         '8종 수술 및 시술 시 가입금액 지급 (1회의 입원 또는 1회의 통원에 한하여 보장)',
#         '골절 수술 시 가입금액 지급',
#         '상해로 사망한 경우 가입금액 지급',
#         '병원 입원시(요양병원 제외) 약관에서 정한 간호·간병통합서비스 사용시 일당지급 (최대 180일)',
#     ],
# }
# ```
# ```
# {
#     'index': [40, 41, 42, 43, 44],
#     '보험 발생(질병)': ['후유장해', '아킬레스힘줄손상', '암', '암(기타피부암 및 갑상선암 제외)', '기타피부암, 갑상선암, 대장점막내암, 제자리암, 경계성종양'],
#     '보장 횟수': ['한도로', '수술받은 경우', '최초 1회한', '연간 1회한', '차회 이후 이 계약의 보험료 납입시마다'],
#     '내용 요약': [
#         '상해사고로 후유장해 발생 시 가입금액 한도로 지급',
#         '상해사고로 아킬레스힘줄손상 수술 받은 경우 가입금액 지급',
#         '암 진단 확정 시 가입금액 지급, 최초 1회한',
#         '암 진단 후 특정치료 받은 경우 가입금액 지급, 연간 1회한',
#         '특정 질병 진단 시 차회 이후 보험료 납입 시마다 특별약관 가입금액 지원'
#     ]
# }
# ```
# ```
# {
#     'index': [45, 46, 47, 48, 49],
#     '보험 발생(질병)': ['아나필락시스', '인공관절치환', '암, 기타피부암, 갑상선암', '암, 기타피부암, 갑상선암', '암, 기타피부암, 갑상선암'],
#     '보장 횟수': ['연간 1회한', '최초 1회한', '연간 1회한', '연간 1회한', '연간 1회한'],
#     '내용 요약': [
#         '응급실에 내원하여 아나필락시스로 진단 확정된 경우 가입금액 지급',
#         '상해 또는 질병으로 인공관절치환 수술을 받은 경우 가입금액 지급. 고관절, 슬관절, 견관절에 한해 보장',
#         '암, 기타피부암, 갑상선암 진단 후 암 특정치료를 받고 연간 총액 1억원 이상인 경우 가입금액 지급',
#         '암, 기타피부암, 갑상선암 진단 후 암 특정치료를 받고 연간 총액 1천만원 이상인 경우 가입금액 지급',
#         '암, 기타피부암, 갑상선암 진단 후 암 특정치료를 받고 연간 총액 2천만원 이상인 경우 가입금액 지급'
#     ]
# }
# ```
# ```
# {
#     'index': [50, 51, 52, 53, 54],
#     '보험 발생(질병)': ['암, 기타피부암 또는 갑상선암', '암, 기타피부암 또는 갑상선암', '암, 기타피부암 또는 갑상선암', '암, 기타피부암 또는 갑상선암', '암, 기타피부암 또는 갑상선암'],
#     '보장 횟수': ['연간 1회한', '연간 1회한', '연간 1회한', '연간 1회한', '연간 1회한'],
#     '내용 요약' : [
#         '암 특정치료를 받아 연간 암 특정치료비 총액이 3천만원 이상인 경우 가입금액 지급',
#         '암 특정치료를 받아 연간 암 특정치료비 총액이 4천만원 이상인 경우 가입금액 지급',
#         '암 특정치료를 받아 연간 암 특정치료비 총액이 5천만원 이상인 경우 가입금액 지급',
#         '암 특정치료를 받아 연간 암 특정치료비 총액이 6천만원 이상인 경우 가입금액 지급',
#         '암 특정치료를 받아 연간 암 특정치료비 총액이 7천만원 이상인 경우 가입금액 지급',
#     ],
# }
# ```
# ```
# {
#     'index': [55, 56, 57, 58, 59],
#     '보험 발생(질병)': ['암, 기타피부암 또는 갑상선암', '암, 기타피부암 또는 갑상선암', '화상', '질병의 치료', '질병의 치료'],
#     '보장 횟수': ['연간 1회한', '연간 1회한', '최초 1회한', '수술시술코드당 연간1회한', '수술시술코드당 연간1회한'],
#     '내용 요약' : [
#         '암, 기타피부암 또는 갑상선암 진단 후 특정치료를 받아 발생한 연간 암 특정치료비 총액이 8천만원 이상일 때 가입금액 지급',
#         '암, 기타피부암 또는 갑상선암 진단 후 특정치료를 받아 발생한 연간 암 특정치료비 총액이 9천만원 이상일 때 가입금액 지급',
#         '신체 표면적으로 20%이상의 3도 화상 또는 부식을 입었을 때 가입금액 지급',
#         '질병의 치료를 목적으로 1종 수술 및 시술을 받았을 때 가입금액 지급',
#         '질병의 치료를 목적으로 2종 수술 및 시술을 받았을 때 가입금액 지급',
#     ],
# }
# ```
# ```
# {
#     'index': [60, 61, 62, 63, 64],
#     '보험 발생(질병)': ['3종 수술 및 시술', '4종 수술 및 시술', '5종 수술 및 시술', '6종 수술 및 시술', '7종 수술 및 시술'],
#     '보장 횟수': ['수술시술코드당 연간1회한', '수술시술코드당 연간1회한', '수술시술코드당 연간1회한', '수술시술코드당 연간1회한', '수술시술코드당 연간1회한'],
#     '내용 요약': [
#         '질병 치료 위해 3종 수술 및 시술 시 가입금액 지급. 1회의 입원 또는 통원당 1회 보장',
#         '질병 치료 위해 4종 수술 및 시술 시 가입금액 지급. 1회의 입원 또는 통원당 1회 보장',
#         '질병 치료 위해 5종 수술 및 시술 시 가입금액 지급. 1회의 입원 또는 통원당 1회 보장',
#         '질병 치료 위해 6종 수술 및 시술 시 가입금액 지급. 1회의 입원 또는 통원당 1회 보장',
#         '질병 치료 위해 7종 수술 및 시술 시 가입금액 지급. 1회의 입원 또는 통원당 1회 보장'
#     ],
# }
# ```
# ```
# {
#     'index': [65, 66, 67, 68, 69],
#     '보험 발생(질병)': ['8종 수술 및 시술', '간호·간병통합서비스', '급성심근경색증', '뇌경색증', '화상'],
#     '보장 횟수': ['수술시술코드당 연간1회', '1일 일당', '최초 1회', '최초 1회', '수술시'],
#     '내용 요약': [
#         '8종 수술 및 시술 받은 경우 가입금액 지급. 1회의 입원당 1회의 수술 및 시술 또는 1회의 통원당 1회의 수술 및 시술에 한하여 보장',
#         '1일 이상 입원하여 간호·간병통합서비스 사용한 경우 가입금액 지급. 180일을 한도로 1일당 일당지급',
#         '급성심근경색증 진단 후 혈전용해 치료 받은 경우 가입금액 지급. 최초 1회',
#         '뇌경색증 진단 후 혈전용해 치료 받은 경우 가입금액 지급. 최초 1회',
#         '심재성 2도 이상 화상 수술 받은 경우 가입금액 지급'
#     ]
# }
# ```
# ```
# {
#     'index': [70],
#     '보험 발생(질병)': ['화상'],
#     '보장 횟수': ['수술시'],
#     '내용 요약': ['심재성 2도 이상 화상 수술 시 가입금액 지급']
# }
# ```

# %%
gpt_answers = []


for response in gpt_responses:
    try:
        response = response.replace('`', '')
        response = response.replace('\n', '')
        response = response.replace('=', '')
        response = response.replace('python', '')
        response = response.replace("'''", '')
        response = "'''" + response + "'''"


        response = ast.literal_eval(response)
        response = ast.literal_eval(response)
        
        gpt_answers.append(response)
    except (SyntaxError, ValueError) as e:
        print(traceback.print_exc())
        break

# %%
gpt_answers[0].keys()
# Out:
# dict_keys(['index', '보험 발생(질병)', '보장 횟수', '내용 요약'])

# %%
result_df=pd.DataFrame(columns=['index', '보험 발생(질병)', '보장 횟수', '내용 요약'])

for answers in gpt_answers:
    try:
        temp_df = pd.DataFrame(answers)
        result_df = pd.concat([result_df, temp_df], join='inner')
    except ValueError as e:
        print(traceback.print_exc())
        print(answers)
        break

# %%
result_df.head()
# Out:
#   index               보험 발생(질병)  보장 횟수  \
# 0     0  복·의원(요양병원 제외) 1일 이상 입원  1일 일당
# 1     1           요양병원 1일 이상 입원  1일 일당
# 2     2             질병 1일 이상 입원  1일 일당
# 3     3        질병 요양병원 1일 이상 입원  1일 일당
# 4     4  복·의원(요양병원 제외) 1일 이상 입원  1일 일당
#
#                                                내용 요약
# 0  상해로 1일 이상 병·의원(요양병원 제외) 입원 시 간병인 사용에 따라 일당 지급,...
# 1  상해로 1일 이상 요양병원 입원시 간병인 사용에 따라 일당 지급, 20년마다 10%...
# 2  질병으로 1일 이상 입원시 간병인 사용에 따라 일당 지급, 7만원 미만 50%, 7...
# 3  질병으로 요양병원 1일 이상 입원시 간병인 사용에 따라 일당 지급, 20년마다 10...
# 4  상해로 1일 이상 병·의원(요양병원 제외) 입원 시 간병인 사용에 따라 일당 지급,...

# %%
result_df = result_df.drop('index', axis=1).reset_index(drop=True)

# %%
data = data.join(result_df)

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
data.drop('보장단위', axis=1, inplace=True)

# %%
data.sample(20)
# Out:
#       유형1   유형2                                 보험 보장 대상  \
# 7      입원  간병인2  (체증형,20년후2배)질병 입원 간병인 사용일당(1 일이상)(요양병원)
# 52     진단     암      종합병원 암 특정치료지원금(연간 5천만원 이상, 진단 후 5년)
# 38  간병/사망    상해                                    상해 사망
# 23     진단    골절                                   골절 진단비
# 10     수술  로봇수술                      [갱신형] 특정암 다빈치로봇 수술비
# 64     수술    질병                          질병 7종 수술비(시술포함)
# 41     수술    상해                             아킬레스힘줄손상 수술비
# 35     수술    상해                          상해 7종 수술비(시술포함)
# 37     수술    상해                                상해 골절 수술비
# 9      수술  로봇수술                [갱신형] 암(특정암 제외) 다빈치로봇 수술비
# 2      입원  간병인1       (체증형)질병 입원 간병인 사용일당(1일이상)(요양병원 제외)
# 58     수술    질병                          질병 1종 수술비(시술포함)
# 53     진단     암      종합병원 암 특정치료지원금(연간 6천만원 이상, 진단 후 5년)
# 69     수술    화상                                   화상 수술비
# 22     진단   갑상선                             갑상선기능항진증 치료비
# 59     수술    질병                          질병 2종 수술비(시술포함)
# 66     입원  간호간병              질병 입원 간호·간병통합서비스 사용일당(1일이상)
# 70     진단    화상                                   화상 진단비
# 31     수술    상해                          상해 3종 수술비(시술포함)
# 28     진단    상해                              보험료 납입면제대상Ⅱ
#
#                                                                                                   상세 설명  \
# 7   보험기간 중 질병으로 요양병원에 1일이상 계속 입원하여 치료를 받으며, 약관에 정한 간병인을 사용한 경우 가입후 20년 미만 시 가입금액의 100% 를 지급, 가입후 20년...
# 52  보장개시일 이후 암, 기타피부암 또는 갑상선암으로 진단 확정되고 「암 보험 금 지급기간」이내에 「종합병원」에서 「암 특정치료」를 받아 발생한 「연간 암 특정치료비 총액」이 ...
# 38                                                                                 상해사고로 사망한 경우 가입금액 지급
# 23                                                                   상해사고로 약관에 정한 골절로 진단 확정된 경우 가입금액 지급
# 10  보장개시일 이후 특정암(갑상선암, 전립선암)으로 진단 확정되고 그 특정암 의 직접적인 치료를 목적으로 다빈치 로봇수술을 받은 경우 가입금액 지급( 최초 1회한)\n※ 특정암...
# 64  보험기간 중 질병의 치료를 직접적인 목적으로 약관에서 정한 7종 수술 및 시술을 받은 경우 가입금액 지급(수술시술코드당 연간1회한)\n※ 1회의 입원당 1회의 「수술 및 시...
# 41                                                     상해사고로 약관에 정한 아킬레스힘줄손상으로 진단확정되어 수술을 받은 경우 가입금액 지급
# 35  보험기간 중 상해의 치료를 직접적인 목적으로 약관에서 정한 7종 수술 및 시술을 받은 경우 가입금액 지급(수술시술코드당 연간1회한)\n※ 1회의 입원당 1회의 「수술 및 시...
# 37                                                                     상해사고로 약관에 정한 골절로 수술받은 경우 가입금액 지급
# 9   보장개시일 이후 암(특정암 제외)으로 진단 확정되고 그 암(특정암 제외)의 직접적인 치료를 목적으로 다빈치 로봇수술을 받은 경우 가입금액 지급(최 초 1회한)\n※ 암(특정...
# 2   보험기간 중 질병으로 병·의원(요양병원 제외) 등에 1일이상 계속 입원하여 치료를 받으며, 약관에 정한 간병인을 사용한 경우 1일당 간병인 사용금액 을 기준으로 차등지급(1...
# 58  보험기간 중 질병의 치료를 직접적인 목적으로 약관에서 정한 1종 수술 및 시술을 받은 경우 가입금액 지급(수술시술코드당 연간1회한)\n※ 1회의 입원당 1회의 「수술 및 시...
# 53  보장개시일 이후 암, 기타피부암 또는 갑상선암으로 진단 확정되고 「암 보험 금 지급기간」이내에 「종합병원」에서 「암 특정치료」를 받아 발생한 「연간 암 특정치료비 총액」이 ...
# 69                                 상해사고로 심재성 2도 이상에 해당하는 화상으로 진단 확정 후 그 치료를 직접적인 목적으로 수술을 받은 경우 가입금액 지급
# 22  보험기간 중 약관에서 정한 「갑상선기능항진증」으로 진단 확정되고 「갑상선 기능항진증 치료」를 받은 경우 가입금액 지급(최초 1회한)\n※ 최초 보험가입후 1년 미만에 보험금...
# 59  보험기간 중 질병의 치료를 직접적인 목적으로 약관에서 정한 2종 수술 및 시술을 받은 경우 가입금액 지급(수술시술코드당 연간1회한)\n※ 1회의 입원당 1회의 「수술 및 시...
# 66  보험기간 중 질병으로 병원(요양병원 제외)에 1일이상 계속 입원하여 치료 를 받으며, 약관에 정한 간호·간병통합서비스를 사용한 경우 가입금액 지급 (180일을 한도로 간호·...
# 70                                                        상해사고로 심재성 2도 이상에 해당하는 화상으로 진단 확정된 경우 가입금 액 지급
# 31  보험기간 중 상해의 치료를 직접적인 목적으로 약관에서 정한 3종 수술 및 시술을 받은 경우 가입금액 지급(수술시술코드당 연간1회한)\n※ 1회의 입원당 1회의 「수술 및 시...
# 28  보장개시일 이후 상해사고로 80%이상 후유장해가 발생하거나 약관에서 정 한 암, 뇌졸중, 급성심근경색증, 중대 화상·부식으로 진단 확정 또는 뇌·내장 손상 수술로 보험료 납...
#
#         보장금액  월 보험료  기본 보험료  할증 보험료   그룹    보장기간  납입기간(년) 갱신여부    총 보험료  \
# 7      30000  10338    7131  3207.0  NaN  100세만기       20    납  2481120
# 52  10000000    808     808     NaN  NaN  100세만기       20    납   193920
# 38  50000000   2550    2550     NaN  NaN  100세만기       20    납   612000
# 23    100000    898     898     NaN  NaN  100세만기       20    납   215520
# 10  10000000    200     200     NaN  NaN  100세만기       10   갱신    24000
# 64   9000000   5056    3410  1646.0    e  100세만기       20    납  1213440
# 41   1000000     60      60     NaN  NaN  100세만기       20    납    14400
# 35  15000000    266     266     NaN    c  100세만기       20    납    63840
# 37    200000    372     372     NaN  NaN  100세만기       20    납    89280
# 9   20000000   1120    1120     NaN  NaN  100세만기       10   갱신   134400
# 2     150000  25297   17265  8032.0  NaN  100세만기       20    납  6071280
# 58    300000   3648    2454  1194.0    d  100세만기       20    납   875520
# 53  10000000    638     638     NaN  NaN  100세만기       20    납   153120
# 69    300000     11      11     NaN  NaN  100세만기       20    납     2640
# 22   2000000    260     260     NaN  NaN  100세만기       20    납    62400
# 59    300000   3646    2453  1193.0    d  100세만기       20    납   875040
# 66     70000   3425    2331  1094.0  NaN  100세만기       20    납   822000
# 70    100000     76      76     NaN  NaN  100세만기       20    납    18240
# 31    450000    546     546     NaN    b  100세만기       20    납   131040
# 28    100000    168     168     NaN  NaN  100세만기       20    납    40320
#
#     보장 대비 납입율                                  보험 발생(질병)  \
# 7   82.704000                                  간병인(요양병원)
# 52   0.019392                           암, 기타피부암 또는 갑상선암
# 38   0.012240                                         사망
# 23   2.155200                                         골절
# 10   0.002400                                 갑상선암, 전립선암
# 64   0.134827                                 7종 수술 및 시술
# 41   0.014400                                   아킬레스힘줄손상
# 35   0.004256                                 7종 수술 및 시술
# 37   0.446400                                         골절
# 9    0.006720                                  암(특정암 제외)
# 2   40.475200                                질병 1일 이상 입원
# 58   2.918400                                     질병의 치료
# 53   0.015312                           암, 기타피부암 또는 갑상선암
# 69   0.008800                                         화상
# 22   0.031200                                   갑상선기능항진증
# 59   2.916800                                     질병의 치료
# 66  11.742857                                 간호·간병통합서비스
# 70   0.182400                                         화상
# 31   0.291200               상해의 치료를 직접적인 목적으로 3종 수술 및 시술
# 28   0.403200  상해, 암, 뇌졸중, 급성심근경색증, 중대 화상·부식, 뇌·내장 손상 수술
#
#                                보장 횟수  \
# 7   가입후 20년 미만 100%, 가입후 20년 이상 200%
# 52                            연간 1회한
# 38                                한번
# 23
# 10                             최초 1회
# 64                     수술시술코드당 연간1회한
# 41                           수술받은 경우
# 35                      수술시술코드당 연간1회
# 37                           수술받은 경우
# 9                              최초 1회
# 2                              1일 일당
# 58                     수술시술코드당 연간1회한
# 53                            연간 1회한
# 69                               수술시
# 22                             최초 1회
# 59                     수술시술코드당 연간1회한
# 66                             1일 일당
# 70                               수술시
# 31                     수술시술코드당 연간1회한
# 28                            최초 1회한
#
#                                                                                            내용 요약
# 7              질병으로 요양병원에 1일이상 계속 입원시 간병인 사용에 따라 일당 지급. 20년 미만 100%, 20년 이상 200% 할증 지급, 최대 180일.
# 52                                                 암 특정치료를 받아 연간 암 특정치료비 총액이 5천만원 이상인 경우 가입금액 지급
# 38                                                                            상해로 사망한 경우 가입금액 지급
# 23                                                                               골절 진단 시 가입금액 지급
# 10                                              특정암 진단 후 다빈치 수술 시 가입금액 지급, 보장개시 90일 후, 초기 감액 있음.
# 64                                            질병 치료 위해 7종 수술 및 시술 시 가입금액 지급. 1회의 입원 또는 통원당 1회 보장
# 41                                                               상해사고로 아킬레스힘줄손상 수술 받은 경우 가입금액 지급
# 35                                               7종 수술 및 시술 시 가입금액 지급 (1회의 입원 또는 1회의 통원에 한하여 보장)
# 37                                                                               골절 수술 시 가입금액 지급
# 9   암(특정암 제외) 진단 후 다빈치 수술 시 가입금액 지급, 보장개시일 90일 후, 최초 180일 내 25% 감액, 1년 내 50% 감액. 특정암: 갑상선암, 전립선암
# 2                       질병으로 1일 이상 입원시 간병인 사용에 따라 일당 지급, 7만원 미만 50%, 7만원 이상 100% 할증 지급, 최대 180일.
# 58                                                        질병의 치료를 목적으로 1종 수술 및 시술을 받았을 때 가입금액 지급
# 53                                                 암 특정치료를 받아 연간 암 특정치료비 총액이 6천만원 이상인 경우 가입금액 지급
# 69                                                                 심재성 2도 이상 화상 수술 받은 경우 가입금액 지급
# 22                                                      갑상선기능항진증 진단 및 치료 시 가입금액 지급, 1년 미만 50% 감액
# 59                                                        질병의 치료를 목적으로 2종 수술 및 시술을 받았을 때 가입금액 지급
# 66                                      1일 이상 입원하여 간호·간병통합서비스 사용한 경우 가입금액 지급. 180일을 한도로 1일당 일당지급
# 70                                                                     심재성 2도 이상 화상 수술 시 가입금액 지급
# 31          약관에서 정한 3종 수술 및 시술을 받은 경우, 수술시술코드당 연간 1회한 가입금액 지급. 1회의 입원 또는 통원당 1회의 수술 및 시술에 한하여 보장
# 28                   상해로 80%이상 후유장해 등 진단 시 가입금액 지급, 암, 뇌졸중, 급성심근경색증 등 진단 또는 수술 시 가입금액 지급, 최초 1회한

# %%
data.to_excel('preprocessed_data_txt-sum.xlsx', index=False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   유형1        71 non-null     object
#  1   유형2        71 non-null     object
#  2   보험 보장 대상   71 non-null     object
#  3   상세 설명      71 non-null     object
#  4   보장금액       71 non-null     int64
#  5   월 보험료      71 non-null     int64
#  6   기본 보험료     71 non-null     int64
#  7   할증 보험료     17 non-null     float64
#  8   그룹         20 non-null     object
#  9   보장기간       71 non-null     object
#  10  납입기간(년)    71 non-null     int64
#  11  갱신여부       71 non-null     object
#  12  총 보험료      71 non-null     int64
#  13  보장 대비 납입율  71 non-null     float64
#  14  보험 발생(질병)  71 non-null     object
#  15  보장 횟수      71 non-null     object
#  16  내용 요약      71 non-null     object
# dtypes: float64(2), int64(5), object(10)
# memory usage: 9.6+ KB

# %%
data.shape
# Out:
# (71, 17)
