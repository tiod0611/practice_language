# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import numpy as np
import re

matplotlib.rcParams['axes.unicode_minus'] =False

# %%
plt.rc('font', family='NanumGothic')
print(plt.rcParams['font.family'])
# Out:
# ['NanumGothic']

# %%
electricity = pd.read_csv("data/electricity_consumption.csv", encoding='cp949', index_col='날짜')
electricity.head(10)
# Out:
#                1시     2시     3시     4시     5시     6시     7시     8시     9시  \
# 날짜
# 2021-01-01  64942  62593  60905  59889  59638  59936  60193  59982  59626
# 2021-01-02  60658  58603  57309  56663  56733  57327  58378  59285  60669
# 2021-01-03  61992  59723  58310  57599  57518  58073  58877  59373  59434
# 2021-01-04  62078  60011  58936  58715  59233  61081  64908  71659  80766
# 2021-01-05  67267  64957  63471  63136  63564  65045  68221  73685  81609
# 2021-01-06  69834  67769  66454  66041  66425  67820  71258  76764  84638
# 2021-01-07  69787  67923  66797  66489  67004  68565  71857  76917  84978
# 2021-01-08  73086  70960  69867  69143  69141  70433  73185  78406  86597
# 2021-01-09  72506  70368  69057  68216  67882  68061  69159  70598  73312
# 2021-01-10  69016  66797  65250  64317  64098  64459  64882  64993  65140
#
#               10시  ...    15시    16시    17시    18시    19시    20시    21시  \
# 날짜                 ...
# 2021-01-01  57904  ...  56691  58299  60425  62931  64176  63645  62754
# 2021-01-02  59515  ...  55493  57865  61407  64223  65082  64257  62981
# 2021-01-03  56835  ...  59465  61355  63202  65426  66473  65646  64815
# 2021-01-04  82796  ...  81315  81431  82840  81666  78838  75717  72867
# 2021-01-05  83240  ...  81611  82647  84497  83721  81513  78460  75423
# 2021-01-06  85568  ...  80703  82423  84890  84026  81286  78156  75065
# 2021-01-07  88741  ...  88570  88791  90195  88593  85675  82103  78767
# 2021-01-08  89506  ...  87873  88394  89749  87970  84470  81091  78254
# 2021-01-09  73146  ...  70652  71328  73094  74004  74232  72796  71222
# 2021-01-10  63661  ...  62778  64543  66813  69439  70738  69913  68716
#
#               22시    23시    24시
# 날짜
# 2021-01-01  61561  61979  63055
# 2021-01-02  61686  61962  64227
# 2021-01-03  63289  63706  64480
# 2021-01-04  69726  68460  70327
# 2021-01-05  72053  70992  72838
# 2021-01-06  71868  71204  72623
# 2021-01-07  75135  74165  75614
# 2021-01-08  74855  73882  75386
# 2021-01-09  69024  69331  71259
# 2021-01-10  67209  67725  68749
#
# [10 rows x 24 columns]

# %%
# 1. 1년 동안 모든 시간대별 사용량 살펴보기
elecTrans = electricity.transpose()
listElect = []
for i in range(len(elecTrans.columns)):
    
    listElect+=(elecTrans.iloc[:,i].to_list())

seriesElect = pd.Series(listElect, )

# %%
plt.figure(figsize=(12, 8))
seriesElect.plot()
current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:.0f}'.format(x) for x in current_values])
plt.show()
# Out:
# C:\Users\kyeul\AppData\Local\Temp\ipykernel_17876\332383880.py:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}'.format(x) for x in current_values])

# %%
# 2. 시간대 평균 사용량
plt.figure(figsize=(12, 8))
electricity.sum(axis=1).plot()
current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:.0f}'.format(x) for x in current_values])
plt.show()
# Out:
# C:\Users\kyeul\AppData\Local\Temp\ipykernel_17876\3289332351.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   electricity.sum(axis=1).plot()
# C:\Users\kyeul\AppData\Local\Temp\ipykernel_17876\3289332351.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}'.format(x) for x in current_values])

# %%
# 월별 평균을 계산하기 위해 month 칼럼 추가
def expectMonth(string):
    return re.findall("[0-9]+", string)[1]
electricity['month'] = electricity.index.to_series().apply(expectMonth)

# %%
plt.figure(figsize=(12, 8))
mean_elect = electricity.groupby('month').mean()
mean_elect.sum(axis=1).plot()
current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:.0f}'.format(x) for x in current_values])
plt.show()
# Out:
# C:\Users\kyeul\AppData\Local\Temp\ipykernel_17876\686801652.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}'.format(x) for x in current_values])

# %%
plt.figure(figsize=(12, 8))
month_elec=electricity.groupby('month').sum()
month_elec.plot()
plt.legend(loc='center right', bbox_to_anchor=(1.2, 0.5))
current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:.0f}'.format(x) for x in current_values])

plt.show()
# Out:
# C:\Users\kyeul\AppData\Local\Temp\ipykernel_17876\115256843.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}'.format(x) for x in current_values])

# %%
month_elec
# Out:
#             1시       2시       3시       4시       5시       6시       7시       8시  \
# month
# 01     2057549  1988293  1948001  1931287  1940244  1976173  2051103  2166104
# 02     1745968  1680324  1643969  1632516  1645553  1683748  1753067  1846958
# 03     1818217  1746168  1711962  1703040  1721495  1770146  1847933  1937209
# 04     1676538  1616019  1586685  1576442  1591340  1629673  1688033  1738683
# 05     1682765  1622372  1591216  1578924  1586577  1609557  1662652  1718300
# 06     1684008  1626347  1593119  1575713  1575707  1594119  1653598  1736705
# 07     1942924  1865796  1817988  1788605  1782284  1799519  1873106  1996198
# 08     1876398  1808211  1766858  1742461  1739789  1763342  1831384  1945112
# 09     1674680  1620402  1588988  1572293  1575584  1606761  1665310  1750027
# 10     1739527  1679330  1645715  1631383  1640627  1680382  1748269  1824891
# 11     1779668  1712773  1677620  1665970  1681321  1729357  1813499  1916979
# 12     2030059  1959339  1917487  1900635  1915934  1961295  2052357  2191347
#
#             9시      10시  ...      15시      16시      17시      18시      19시  \
# month                    ...
# 01     2328086  2337643  ...  2245022  2273508  2330747  2332042  2311580
# 02     1955041  1941212  ...  1821475  1847184  1904022  1919110  1945126
# 03     2027230  2004026  ...  1867470  1903240  1962100  2000730  2043538
# 04     1794868  1775654  ...  1734469  1771719  1825105  1857170  1888168
# 05     1797184  1812027  ...  1815635  1846337  1888310  1908410  1927855
# 06     1852436  1899686  ...  1972615  1995587  2033084  2032071  2022453
# 07     2174111  2279181  ...  2437020  2457083  2489315  2488773  2467281
# 08     2104733  2193613  ...  2322096  2338706  2360926  2364019  2346507
# 09     1853617  1893537  ...  1971528  2000290  2036407  2041477  2046403
# 10     1895978  1891713  ...  1913327  1959155  2024213  2051542  2072386
# 11     2018079  1993593  ...  1964097  2009478  2071893  2075442  2064469
# 12     2360556  2355655  ...  2256499  2303824  2370118  2367029  2329435
#
#            20시      21시      22시      23시      24시
# month
# 01     2251200  2188706  2112476  2093635  2140033
# 02     1919450  1880273  1830352  1803754  1831309
# 03     2048477  2003399  1960008  1927231  1930315
# 04     1913313  1881470  1839721  1798517  1781865
# 05     1947689  1930953  1882871  1828640  1789926
# 06     2018811  1991933  1923029  1840338  1795241
# 07     2450663  2400842  2290463  2158067  2080401
# 08     2339186  2274172  2166331  2047927  1988001
# 09     2034328  1973144  1899237  1814924  1770737
# 10     2039603  1988928  1932742  1873092  1840696
# 11     2025075  1986702  1939603  1898667  1899929
# 12     2275702  2220209  2153831  2115919  2136462
#
# [12 rows x 24 columns]

# %%
# 1. 매월 시간대별 평균 사용량 살펴보기
monthElecTrans = month_elec.transpose()
listmonth = []
for i in range(len(monthElecTrans.columns)):
    
    listmonth+=(monthElecTrans.iloc[:,i].to_list())

seriesMonthElect = pd.Series(listmonth)

# %%
plt.figure(figsize=(12, 8))
seriesMonthElect.plot()
current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:.0f}'.format(x) for x in current_values])
plt.show()
# Out:
# C:\Users\kyeul\AppData\Local\Temp\ipykernel_17876\782391549.py:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}'.format(x) for x in current_values])
