# %%
import requests
import lxml
import json

# %%
url = 'https://smartstore.naver.com/i/v1/contents/reviews/query-pages'
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36",
    "Referer": "https://smartstore.naver.com/hotsunglass/products/5414655144?NaPm=ct%3Dlv9lb59s%7Cci%3D1a688e8bf3691696311e3c8089a42dd002b73a30%7Ctr%3Dnshfu%7Csn%3D166710%7Chk%3D2e978bd740b0c92c2af005000148a9b94c2298f8",
    "Content-Length": 124,
    ":authority": "smartstore.naver.com",
    ":method": "POST",
    ":path": "/i/v1/contents/reviews/query-pages",
    ":scheme": "https",
    "Content-Type": "application/json",
    "Origin": "https://smartstore.naver.com",
    "Pragma": "no-cache",
    "Priority": "u=1, i",

}
params = {
    ":authority": "smartstore.naver.com",
    ":method": "POST",
    ":path": "/i/v1/contents/reviews/query-pages",
    ":scheme": "https",
    "Accept": "application/json, text/plain, */*",
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
    "Cache-Control": "no-cache",
    "Content-Length": 124,
    "Content-Type": "application/json",
    "Origin": "https://smartstore.naver.com",
    "Pragma": "no-cache",
    "Priority": "u=1, i",
    "Referer": "https://smartstore.naver.com/hotsunglass/products/5414655144?NaPm=ct%3Dlv9lb59s%7Cci%3D1a688e8bf3691696311e3c8089a42dd002b73a30%7Ctr%3Dnshfu%7Csn%3D166710%7Chk%3D2e978bd740b0c92c2af005000148a9b94c2298f8",
    "Sec-Ch-Ua": '"Chromium";v="124", "Google Chrome";v="124", "Not-A.Brand";v="99"',
    "Sec-Ch-Ua-Mobile": "?0",
    "Sec-Ch-Ua-Platform": '"Windows"',
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36",
    "X-Client-Version": "20240417191414",
}

# %%
response = requests.post(url, headers=headers)
response
# Out:
# <Response [503]>
